# %% [markdown]
# <a href="https://colab.research.google.com/github/Minoo-eml/pipedream/blob/master/minooproject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # **INTRODUCING THE DATA**

# %%
stroke = pd.read_csv('/content/healthcare-dataset-stroke-data.csv')

# %%
stroke.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %% [markdown]
# **What is the items**?
# 1) id: unique identifier
# 2) gender: "Male", "Female" or "Other"
# 3) age: age of the patient
# 4) hypertension: 0 if the patient doesn't have hypertension, 1 if the patient has hypertension
# 5) heart_disease: 0 if the patient doesn't have any heart diseases, 1 if the patient has a heart disease
# 6) ever_married: "No" or "Yes"
# 7) work_type: "children", "Govt_jov", "Never_worked", "Private" or "Self-employed"
# 8) Residence_type: "Rural" or "Urban"
# 9) avg_glucose_level: average glucose level in blood
# 10) bmi: body mass index
# 11) smoking_status: "formerly smoked", "never smoked", "smokes" or "Unknown"*
# 12) stroke: 1 if the patient had a stroke or 0 if not

# %%
stroke.tail()
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 5105        Private          Urban              83.75   NaN     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0

# %%
stroke.shape
# Out:
# (5110, 12)

# %%
# how many typle have each column
stroke.nunique()
# Out:
# id                   5110
# gender                  3
# age                   104
# hypertension            2
# heart_disease           2
# ever_married            2
# work_type               5
# Residence_type          2
# avg_glucose_level    3979
# bmi                   418
# smoking_status          4
# stroke                  2
# dtype: int64

# %%
# the type of the each column
stroke.dtypes
# Out:
# id                     int64
# gender                object
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married          object
# work_type             object
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# stroke                 int64
# dtype: object

# %%
hadstroke = stroke[stroke['stroke']==1]
hadntstroke = stroke[stroke['stroke']==0]

# %%
# number al our total values in data and how mach stroke and not stroke
print('total =' , len(stroke))
print('number of people who had stroke  =' ,len(hadstroke) )
print('number of people who hadnot stroke =' ,len(hadntstroke) )
# Out:
# total = 5110
# number of people who had stroke  = 249
# number of people who hadnot stroke = 4861

# %%
stroke.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
stroke.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.500000     0.000000
# 50%            91.885000    28.100000     0.000000
# 75%           114.090000    33.100000     0.000000
# max           271.740000    97.600000     1.000000

# %% [markdown]
# # **Data Exploration**

# %%
stroke.head(5)
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
# number of the people that had stroke(1) or not(0)
stroke['stroke'].value_counts()
# Out:
# 0    4861
# 1     249
# Name: stroke, dtype: int64

# %%
# number of the each type of the gender
stroke.gender.value_counts().head()
# Out:
# Female    2994
# Male      2115
# Other        1
# Name: gender, dtype: int64

# %%
# number of the each type of the work
stroke.work_type.value_counts().head()
# Out:
# Private          2925
# Self-employed     819
# children          687
# Govt_job          657
# Never_worked       22
# Name: work_type, dtype: int64

# %%
# number of the each type of smoking status
stroke.smoking_status.value_counts().head()
# Out:
# never smoked       1892
# Unknown            1544
# formerly smoked     885
# smokes              789
# Name: smoking_status, dtype: int64

# %%
# number of the different type of the gender divided by smoking status
pd.crosstab(stroke["gender"] , stroke["smoking_status"])
# Out:
# smoking_status  Unknown  formerly smoked  never smoked  smokes
# gender
# Female              836              477          1229     452
# Male                708              407           663     337
# Other                 0                1             0       0

# %%
# number of the different type of the gender divided by work types
pd.crosstab(stroke["gender"] , stroke["work_type"])
# Out:
# work_type  Govt_job  Never_worked  Private  Self-employed  children
# gender
# Female          399            11     1754            504       326
# Male            258            11     1170            315       361
# Other             0             0        1              0         0

# %%
# number of the different type of the gender divided by resident status
pd.crosstab(stroke["gender"] , stroke["Residence_type"])
# Out:
# Residence_type  Rural  Urban
# gender
# Female           1465   1529
# Male             1048   1067
# Other               1      0

# %%
# number of the different type of the work types divided by smoking status
pd.crosstab(stroke["work_type"] , stroke["smoking_status"])
# Out:
# smoking_status  Unknown  formerly smoked  never smoked  smokes
# work_type
# Govt_job            122              133           282     120
# Never_worked          8                0            14       0
# Private             640              531          1211     543
# Self-employed       156              208           331     124
# children            618               13            54       2

# %%
 lab = stroke['smoking_status'].value_counts()
 labels = lab.index
 plt.figure(figsize=(6,10))
 plt.pie(stroke['smoking_status'].value_counts().head(5),labels= labels, autopct='%.2f%%', startangle=90)
 plt.title('smoking division', fontweight='bold', fontsize=14)
 plt.legend()
 plt.legend(loc="upper left")
 plt.show()

# %%
 lab = stroke['work_type'].value_counts()
 labels = lab.index
 plt.figure(figsize=(6,10))
 plt.pie(stroke['work_type'].value_counts().head(5),labels= labels, autopct='%.2f%%', startangle=90)
 plt.title('participants by work type', fontweight='bold', fontsize=14)
 plt.legend()
 plt.legend(loc="upper left")
 plt.show()

# %%
plt.figure(figsize=[26,10])
plt.subplot(251)
stroke['age'].hist(bins=40)
plt.subplot(252)
sns.countplot( stroke['gender'] , color='pink')
plt.subplot(253)
sns.countplot( stroke['ever_married'] , color='black')
plt.subplot(254)
sns.countplot( stroke['work_type'] , color='blue')
plt.subplot(255)
sns.countplot( stroke['smoking_status'] , color='yellow')
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(x='gender' , y='age' , data=stroke)

# %%
plt.figure(figsize=[22,10])
plt.subplot(241)
sns.countplot(x='gender' ,hue='stroke', data=stroke , color= 'black')
plt.subplot(242)
sns.countplot(x='smoking_status' ,hue='stroke', data=stroke ,color='salmon')
plt.subplot(243)
sns.countplot(x='hypertension' ,hue='stroke', data=stroke ,color='pink')
plt.subplot(244)
sns.countplot(x='heart_disease' ,hue='stroke', data=stroke , color='blue')
plt.show()

# %%
plt.figure(figsize=[20,6])
plt.subplot(131)
sns.countplot(x='work_type' ,hue='stroke', data=stroke , color='black')
plt.subplot(132)
sns.countplot(x='Residence_type' ,hue='stroke', data=stroke , color='pink')
plt.subplot(133)
sns.countplot(x='smoking_status' ,hue='stroke', data=stroke , color='blue')
plt.show()

# %%
plt.figure(figsize=[24,6])
sns.countplot(x='age' ,hue='stroke', data=stroke)

# %%
stroke.corr()
# Out:
#                          id       age  hypertension  heart_disease  \
# id                 1.000000  0.003538      0.003550      -0.001296
# age                0.003538  1.000000      0.276398       0.263796
# hypertension       0.003550  0.276398      1.000000       0.108306
# heart_disease     -0.001296  0.263796      0.108306       1.000000
# avg_glucose_level  0.001092  0.238171      0.174474       0.161857
# bmi                0.003084  0.333398      0.167811       0.041357
# stroke             0.006388  0.245257      0.127904       0.134914
#
#                    avg_glucose_level       bmi    stroke
# id                          0.001092  0.003084  0.006388
# age                         0.238171  0.333398  0.245257
# hypertension                0.174474  0.167811  0.127904
# heart_disease               0.161857  0.041357  0.134914
# avg_glucose_level           1.000000  0.175502  0.131945
# bmi                         0.175502  1.000000  0.042374
# stroke                      0.131945  0.042374  1.000000

# %%
# showing the corellation amounge items 
plt.figure(figsize=(12,8))
sns.heatmap(stroke.corr(), annot=True)

# %% [markdown]
# # **cleaning data**

# %%
# the count of empty values
stroke.isnull().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
# showing the nun values with blue color
sns.heatmap(stroke.isnull() , yticklabels=False ,cbar=False ,cmap='Blues')

# %%
# counting the number of null values of bmi column
stroke['bmi'].isnull().sum()
# Out:
# 201

# %%
# removing that values that thay are empty
stroke.dropna(subset=['bmi'], inplace=True)

# %%
sns.heatmap(stroke.isnull() , yticklabels=False ,cbar=False ,cmap='Blues')

# %%
hadstroke = stroke[stroke['stroke']==1]
hadntstroke = stroke[stroke['stroke']==0]

# %%
# the number of total and stroke and not stroke after draping the nun values
print('total =' , len(stroke))
print('number of people who had stroke  =' ,len(hadstroke) )
print('number of people who hadnot stroke =' ,len(hadntstroke) )
# Out:
# total = 4909
# number of people who had stroke  = 209
# number of people who hadnot stroke = 4700

# %%
# droping the colums that thay are not important for prediction
stroke = stroke.drop(['id'] , axis=1)

# %% [markdown]
# # **More exploration on data**

# %%
stroke.head(5)
# Out:
#    gender   age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  67.0             0              1          Yes        Private
# 2    Male  80.0             0              1          Yes        Private
# 3  Female  49.0             0              0          Yes        Private
# 4  Female  79.0             1              0          Yes  Self-employed
# 5    Male  81.0             0              0          Yes        Private
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban             228.69  36.6  formerly smoked       1
# 2          Rural             105.92  32.5     never smoked       1
# 3          Urban             171.23  34.4           smokes       1
# 4          Rural             174.12  24.0     never smoked       1
# 5          Urban             186.21  29.0  formerly smoked       1

# %%
# calculating the count of the different type of gender that thay had stroke
grouped = stroke.groupby('gender')
grouped_sum = grouped['stroke'].sum()
print(grouped_sum)
print(grouped_sum/209*100)
a = grouped_sum/209*100
# Out:
# gender
# Female    120
# Male       89
# Other       0
# Name: stroke, dtype: int64
# gender
# Female    57.416268
# Male      42.583732
# Other      0.000000
# Name: stroke, dtype: float64

# %%
# calculating the two range of the age that they had stroke
minoo = stroke[(stroke['stroke'] == 1) & (stroke['age'] >50)]
arpi = stroke[(stroke['stroke'] == 1) & (stroke['age'] <50)]
print(len(minoo))
print(len(arpi))
# Out:
# 188
# 18

# %%
# calculating the count of the different type of hypertension that thay had stroke
grouped = stroke.groupby('hypertension')
grouped_sum = grouped['stroke'].sum()
print(grouped_sum)
print(grouped_sum/209*100)
b = grouped_sum/209*100
# Out:
# hypertension
# 0    149
# 1     60
# Name: stroke, dtype: int64
# hypertension
# 0    71.291866
# 1    28.708134
# Name: stroke, dtype: float64

# %%
# calculating the count of the different type of heart disease that thay had stroke
grouped = stroke.groupby('heart_disease')
grouped_sum = grouped['stroke'].sum()
print(grouped_sum)
print(grouped_sum/209*100)
c = grouped_sum/209*100
# Out:
# heart_disease
# 0    169
# 1     40
# Name: stroke, dtype: int64
# heart_disease
# 0    80.861244
# 1    19.138756
# Name: stroke, dtype: float64

# %%
# explane the meaning of heart disease numbers
minoo = stroke[(stroke['stroke'] == 0) & (stroke['heart_disease'] ==0 )]
arpi = stroke[(stroke['stroke'] == 0) & (stroke['heart_disease'] ==1 )]
arpi1 = stroke[(stroke['stroke'] == 1) & (stroke['heart_disease'] ==0 )]
arpi2 = stroke[(stroke['stroke'] == 1) & (stroke['heart_disease'] ==1 )]
print(len(minoo))
print(len(arpi))
print(len(arpi1))
print(len(arpi2))
# Out:
# 4497
# 203
# 169
# 40

# %%
# calculating the count of the different type of marrage station that thay had stroke
grouped = stroke.groupby('ever_married')
grouped_sum = grouped['stroke'].sum()
print(grouped_sum)
print(grouped_sum/209*100)
# Out:
# ever_married
# No      23
# Yes    186
# Name: stroke, dtype: int64
# ever_married
# No     11.004785
# Yes    88.995215
# Name: stroke, dtype: float64

# %%
# calculating the count of the different type of worke that thay had stroke
grouped = stroke.groupby('work_type')
grouped_sum = grouped['stroke'].sum()
print(grouped_sum)
print(grouped_sum/209*100)
# Out:
# work_type
# Govt_job          28
# Never_worked       0
# Private          127
# Self-employed     53
# children           1
# Name: stroke, dtype: int64
# work_type
# Govt_job         13.397129
# Never_worked      0.000000
# Private          60.765550
# Self-employed    25.358852
# children          0.478469
# Name: stroke, dtype: float64

# %%
# calculating the count of the different type of residence that thay had stroke
grouped = stroke.groupby('Residence_type')
grouped_sum = grouped['stroke'].sum()
print(grouped_sum)
print(grouped_sum/209*100)
# Out:
# Residence_type
# Rural    100
# Urban    109
# Name: stroke, dtype: int64
# Residence_type
# Rural    47.84689
# Urban    52.15311
# Name: stroke, dtype: float64

# %%
# calculating the count of the different type of smoke status that thay had stroke
grouped = stroke.groupby('smoking_status')
grouped_sum = grouped['stroke'].sum()
print(grouped_sum)
print(grouped_sum/209*100)
# Out:
# smoking_status
# Unknown            29
# formerly smoked    57
# never smoked       84
# smokes             39
# Name: stroke, dtype: int64
# smoking_status
# Unknown            13.875598
# formerly smoked    27.272727
# never smoked       40.191388
# smokes             18.660287
# Name: stroke, dtype: float64

# %% [markdown]
# # **working on data and prediction**

# %%
stroke
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 2       Male  80.0             0              1          Yes        Private
# 3     Female  49.0             0              0          Yes        Private
# 4     Female  79.0             1              0          Yes  Self-employed
# 5       Male  81.0             0              0          Yes        Private
# ...      ...   ...           ...            ...          ...            ...
# 5104  Female  13.0             0              0           No       children
# 5106  Female  81.0             0              0          Yes  Self-employed
# 5107  Female  35.0             0              0          Yes  Self-employed
# 5108    Male  51.0             0              0          Yes        Private
# 5109  Female  44.0             0              0          Yes       Govt_job
#
#      Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0             Urban             228.69  36.6  formerly smoked       1
# 2             Rural             105.92  32.5     never smoked       1
# 3             Urban             171.23  34.4           smokes       1
# 4             Rural             174.12  24.0     never smoked       1
# 5             Urban             186.21  29.0  formerly smoked       1
# ...             ...                ...   ...              ...     ...
# 5104          Rural             103.08  18.6          Unknown       0
# 5106          Urban             125.20  40.0     never smoked       0
# 5107          Rural              82.99  30.6     never smoked       0
# 5108          Rural             166.29  25.6  formerly smoked       0
# 5109          Urban              85.28  26.2          Unknown       0
#
# [4909 rows x 11 columns]

# %%
# defining function for changing string values to numeric values for better modelling in prediction
from sklearn import preprocessing
def strtoint(convert):
    le = preprocessing.LabelEncoder()
    for column in convert.columns:
        convert[column] = le.fit_transform(convert[column])
    return convert

# %%
strtoint(stroke)
# Out:
#       gender  age  hypertension  heart_disease  ever_married  work_type  \
# 0          1   88             0              1             1          2
# 2          1  101             0              1             1          2
# 3          0   70             0              0             1          2
# 4          0  100             1              0             1          3
# 5          1  102             0              0             1          2
# ...      ...  ...           ...            ...           ...        ...
# 5104       0   34             0              0             0          4
# 5106       0  102             0              0             1          3
# 5107       0   56             0              0             1          3
# 5108       1   72             0              0             1          2
# 5109       0   65             0              0             1          0
#
#       Residence_type  avg_glucose_level  bmi  smoking_status  stroke
# 0                  1               3734  239               1       1
# 2                  0               2429  198               2       1
# 3                  1               3309  217               3       1
# 4                  0               3318  113               2       1
# 5                  1               3367  163               1       1
# ...              ...                ...  ...             ...     ...
# 5104               0               2324   59               0       0
# 5106               1               2960  273               2       0
# 5107               0               1290  179               2       0
# 5108               0               3289  129               1       0
# 5109               1               1426  135               0       0
#
# [4909 rows x 11 columns]

# %%
x=stroke.drop('stroke' ,axis=1).values
y=stroke['stroke'].values

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(x,y , test_size=0.2 , random_state=0)

# %%
unique, counts = np.unique( y_train, return_counts=True)
print (np.asarray((unique, counts)).T)
unique, counts = np.unique( y_test, return_counts=True)
print (np.asarray((unique, counts)).T)
# Out:
# [[   0 3761]
#  [   1  166]]
# [[  0 939]
#  [  1  43]]

# %% [markdown]
# our data is not balance so we use SMOTE to balance data.
# What is SMOTE? https://machinelearningmastery.com/smote-oversampling-for-imbalanced-classification/

# %%
from imblearn.over_sampling import SMOTE

# %%
sm=SMOTE(random_state=0)
X_res, y_res = sm.fit_resample(x_train,y_train)

# %%
unique, counts = np.unique( y_res, return_counts=True)
print (np.asarray((unique, counts)).T)
unique, counts = np.unique( y_test, return_counts=True)
print (np.asarray((unique, counts)).T)
# Out:
# [[   0 3761]
#  [   1 3761]]
# [[  0 939]
#  [  1  43]]

# %% [markdown]
# **prediction with LogesticRegration Model**

# %%
# we use this model before balancing ---> the prediction in our stroke = 1 is bad 
from sklearn.linear_model import LogisticRegression
lo= LogisticRegression(random_state=0)
lo.fit(x_train, y_train)
y_predict = lo.predict(x_test)
from sklearn.metrics import classification_report
print(classification_report(y_test , y_predict))
pd.crosstab(y_test , y_predict)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98       939
#            1       0.20      0.02      0.04        43
#
#     accuracy                           0.95       982
#    macro avg       0.58      0.51      0.51       982
# weighted avg       0.92      0.95      0.94       982
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# col_0    0  1
# row_0
# 0      935  4
# 1       42  1

# %%
# after balancing the data ---> our result in prediction is better
from sklearn.linear_model import LogisticRegression
lo= LogisticRegression(random_state=0)
lo.fit(X_res, y_res)
y_predict = lo.predict(x_test)
from sklearn.metrics import classification_report
print(classification_report(y_test , y_predict))
pd.crosstab(y_test , y_predict)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.73      0.84       939
#            1       0.09      0.60      0.16        43
#
#     accuracy                           0.73       982
#    macro avg       0.54      0.67      0.50       982
# weighted avg       0.94      0.73      0.81       982
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# col_0    0    1
# row_0
# 0      690  249
# 1       17   26

# %%
from sklearn.metrics import accuracy_score
a=accuracy_score(y_test, y_predict)
a
# Out:
# 0.7291242362525459

# %% [markdown]
# so we prefer to use SMOTE and balancing our data

# %% [markdown]
# **K_nearestneighbors**

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier= KNeighborsClassifier(n_neighbors = 5 , metric= 'minkowski' , p=2)
classifier.fit(X_res, y_res)
y_predict = classifier.predict(x_test)
from sklearn.metrics import classification_report
print(classification_report(y_test , y_predict))
pd.crosstab(y_test , y_predict)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.75      0.85       939
#            1       0.09      0.53      0.15        43
#
#     accuracy                           0.74       982
#    macro avg       0.53      0.64      0.50       982
# weighted avg       0.93      0.74      0.81       982
# col_0    0    1
# row_0
# 0      702  237
# 1       20   23

# %%
from sklearn.metrics import accuracy_score
b=accuracy_score(y_test, y_predict)
b
# Out:
# 0.7382892057026477

# %% [markdown]
# **Decision Trees and random forest**

# %%
from sklearn.ensemble import RandomForestClassifier
random = RandomForestClassifier(n_estimators=100 , criterion='entropy')
random.fit(X_res, y_res)
y_predict= random.predict(x_test)
from sklearn.metrics import classification_report
print(classification_report(y_test , y_predict))
pd.crosstab(y_test , y_predict)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.92      0.94       939
#            1       0.14      0.30      0.20        43
#
#     accuracy                           0.89       982
#    macro avg       0.56      0.61      0.57       982
# weighted avg       0.93      0.89      0.91       982
# col_0    0   1
# row_0
# 0      862  77
# 1       30  13

# %%
from sklearn.metrics import accuracy_score
c=accuracy_score(y_test, y_predict)
c
# Out:
# 0.8910386965376782

# %% [markdown]
# **Naive bayes classification**

# %%
from sklearn.naive_bayes import MultinomialNB
classifier=MultinomialNB()
classifier.fit(X_res, y_res)
y_predict=classifier.predict(x_test)
from sklearn.metrics import classification_report ,confusion_matrix
cm=confusion_matrix(y_test , y_predict)
sns.heatmap(cm, annot=True )

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test , y_predict))
pd.crosstab(y_test , y_predict)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.55      0.70       939
#            1       0.06      0.63      0.11        43
#
#     accuracy                           0.55       982
#    macro avg       0.51      0.59      0.40       982
# weighted avg       0.93      0.55      0.67       982
# col_0    0    1
# row_0
# 0      512  427
# 1       16   27

# %%
from sklearn.metrics import accuracy_score
d=accuracy_score(y_test, y_predict)
d
# Out:
# 0.5488798370672098

# %% [markdown]
# **xgboost**

# %%
from xgboost import XGBClassifier
model = XGBClassifier()
model.fit(X_res, y_res)
y_predict=model.predict(x_test)
from sklearn.metrics import classification_report ,confusion_matrix
cm=confusion_matrix(y_test , y_predict)
sns.heatmap(cm, annot=True )

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test , y_predict))
pd.crosstab(y_test , y_predict)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.82      0.89       939
#            1       0.11      0.51      0.19        43
#
#     accuracy                           0.80       982
#    macro avg       0.54      0.66      0.54       982
# weighted avg       0.94      0.80      0.86       982
# col_0    0    1
# row_0
# 0      768  171
# 1       21   22

# %%
from sklearn.metrics import accuracy_score
e=accuracy_score(y_test, y_predict)
e
# Out:
# 0.8044806517311609

# %% [markdown]
# **catboost**

# %%
from catboost import CatBoostClassifier
cat=CatBoostClassifier()
cat.fit(X_res,y_res)
y_predict=model.predict(x_test)
from sklearn.metrics import classification_report ,confusion_matrix
cm=confusion_matrix(y_test , y_predict)
sns.heatmap(cm, annot=True )
# Out:
# Learning rate set to 0.024385
# 0:	learn: 0.6746014	total: 4.01ms	remaining: 4s
# 1:	learn: 0.6593627	total: 7.3ms	remaining: 3.64s
# 2:	learn: 0.6438644	total: 9.52ms	remaining: 3.16s
# 3:	learn: 0.6295818	total: 11.8ms	remaining: 2.94s
# 4:	learn: 0.6158568	total: 14ms	remaining: 2.78s
# 5:	learn: 0.6021575	total: 16.4ms	remaining: 2.72s
# 6:	learn: 0.5902740	total: 18.8ms	remaining: 2.67s
# 7:	learn: 0.5770570	total: 21.3ms	remaining: 2.64s
# 8:	learn: 0.5663763	total: 23.8ms	remaining: 2.62s
# 9:	learn: 0.5543209	total: 26.2ms	remaining: 2.59s
# 10:	learn: 0.5461117	total: 28.6ms	remaining: 2.58s
# 11:	learn: 0.5385341	total: 31.1ms	remaining: 2.56s
# 12:	learn: 0.5294256	total: 33.3ms	remaining: 2.53s
# 13:	learn: 0.5221924	total: 35.7ms	remaining: 2.51s
# 14:	learn: 0.5141617	total: 38.2ms	remaining: 2.51s
# 15:	learn: 0.5060374	total: 52.5ms	remaining: 3.23s
# 16:	learn: 0.4994192	total: 55.6ms	remaining: 3.21s
# 17:	learn: 0.4928460	total: 60.2ms	remaining: 3.28s
# 18:	learn: 0.4871909	total: 62.5ms	remaining: 3.23s
# 19:	learn: 0.4798570	total: 64.7ms	remaining: 3.17s
# 20:	learn: 0.4742380	total: 67ms	remaining: 3.12s
# 21:	learn: 0.4698403	total: 69.3ms	remaining: 3.08s
# 22:	learn: 0.4637827	total: 72.1ms	remaining: 3.06s
# 23:	learn: 0.4593627	total: 74.6ms	remaining: 3.03s
# 24:	learn: 0.4547062	total: 77.2ms	remaining: 3.01s
# 25:	learn: 0.4501697	total: 79.6ms	remaining: 2.98s
# 26:	learn: 0.4462322	total: 82.5ms	remaining: 2.97s
# 27:	learn: 0.4418587	total: 84.9ms	remaining: 2.94s
# 28:	learn: 0.4382687	total: 87.3ms	remaining: 2.92s
# 29:	learn: 0.4349762	total: 89.9ms	remaining: 2.91s
# 30:	learn: 0.4314175	total: 92.5ms	remaining: 2.89s
# 31:	learn: 0.4284834	total: 95.2ms	remaining: 2.88s
# 32:	learn: 0.4255450	total: 98ms	remaining: 2.87s
# 33:	learn: 0.4230271	total: 101ms	remaining: 2.86s
# 34:	learn: 0.4188323	total: 104ms	remaining: 2.87s
# 35:	learn: 0.4151911	total: 112ms	remaining: 3s
# 36:	learn: 0.4110835	total: 114ms	remaining: 2.98s
# 37:	learn: 0.4081347	total: 117ms	remaining: 2.97s
# 38:	learn: 0.4058481	total: 120ms	remaining: 2.95s
# 39:	learn: 0.4032021	total: 122ms	remaining: 2.94s
# 40:	learn: 0.4010294	total: 125ms	remaining: 2.92s
# 41:	learn: 0.3982783	total: 127ms	remaining: 2.9s
# 42:	learn: 0.3964240	total: 130ms	remaining: 2.89s
# 43:	learn: 0.3946623	total: 132ms	remaining: 2.87s
# 44:	learn: 0.3925456	total: 135ms	remaining: 2.86s
# 45:	learn: 0.3905247	total: 137ms	remaining: 2.84s
# 46:	learn: 0.3884403	total: 139ms	remaining: 2.83s
# 47:	learn: 0.3867373	total: 142ms	remaining: 2.82s
# 48:	learn: 0.3846974	total: 144ms	remaining: 2.8s
# 49:	learn: 0.3829172	total: 147ms	remaining: 2.79s
# 50:	learn: 0.3809848	total: 150ms	remaining: 2.78s
# 51:	learn: 0.3795682	total: 152ms	remaining: 2.77s
# 52:	learn: 0.3773564	total: 155ms	remaining: 2.77s
# 53:	learn: 0.3753552	total: 158ms	remaining: 2.76s
# 54:	learn: 0.3737756	total: 160ms	remaining: 2.75s
# 55:	learn: 0.3719393	total: 163ms	remaining: 2.74s
# 56:	learn: 0.3703287	total: 165ms	remaining: 2.73s
# 57:	learn: 0.3690248	total: 168ms	remaining: 2.73s
# 58:	learn: 0.3674958	total: 171ms	remaining: 2.73s
# 59:	learn: 0.3656574	total: 173ms	remaining: 2.71s
# 60:	learn: 0.3643004	total: 176ms	remaining: 2.7s
# 61:	learn: 0.3623981	total: 178ms	remaining: 2.69s
# 62:	learn: 0.3606070	total: 181ms	remaining: 2.69s
# 63:	learn: 0.3591960	total: 184ms	remaining: 2.69s
# 64:	learn: 0.3576200	total: 187ms	remaining: 2.69s
# 65:	learn: 0.3558933	total: 189ms	remaining: 2.68s
# 66:	learn: 0.3548142	total: 192ms	remaining: 2.67s
# 67:	learn: 0.3534401	total: 195ms	remaining: 2.68s
# 68:	learn: 0.3518433	total: 198ms	remaining: 2.67s
# 69:	learn: 0.3508688	total: 201ms	remaining: 2.68s
# 70:	learn: 0.3498112	total: 205ms	remaining: 2.68s
# 71:	learn: 0.3483194	total: 207ms	remaining: 2.67s
# 72:	learn: 0.3473386	total: 210ms	remaining: 2.67s
# 73:	learn: 0.3460358	total: 213ms	remaining: 2.67s
# 74:	learn: 0.3449009	total: 215ms	remaining: 2.66s
# 75:	learn: 0.3436940	total: 219ms	remaining: 2.66s
# 76:	learn: 0.3428445	total: 221ms	remaining: 2.65s
# 77:	learn: 0.3415443	total: 224ms	remaining: 2.64s
# 78:	learn: 0.3406578	total: 227ms	remaining: 2.65s
# 79:	learn: 0.3396452	total: 230ms	remaining: 2.64s
# 80:	learn: 0.3386714	total: 232ms	remaining: 2.64s
# 81:	learn: 0.3378015	total: 235ms	remaining: 2.63s
# 82:	learn: 0.3371589	total: 237ms	remaining: 2.62s
# 83:	learn: 0.3362241	total: 240ms	remaining: 2.61s
# 84:	learn: 0.3351714	total: 242ms	remaining: 2.61s
# 85:	learn: 0.3343616	total: 245ms	remaining: 2.6s
# 86:	learn: 0.3335663	total: 247ms	remaining: 2.59s
# 87:	learn: 0.3324942	total: 250ms	remaining: 2.59s
# 88:	learn: 0.3315058	total: 252ms	remaining: 2.58s
# 89:	learn: 0.3303708	total: 255ms	remaining: 2.58s
# 90:	learn: 0.3294525	total: 257ms	remaining: 2.57s
# 91:	learn: 0.3288405	total: 260ms	remaining: 2.56s
# 92:	learn: 0.3280426	total: 262ms	remaining: 2.56s
# 93:	learn: 0.3274023	total: 265ms	remaining: 2.55s
# 94:	learn: 0.3264211	total: 267ms	remaining: 2.55s
# 95:	learn: 0.3258618	total: 270ms	remaining: 2.54s
# 96:	learn: 0.3240566	total: 272ms	remaining: 2.54s
# 97:	learn: 0.3234463	total: 275ms	remaining: 2.53s
# 98:	learn: 0.3221552	total: 278ms	remaining: 2.53s
# 99:	learn: 0.3213441	total: 280ms	remaining: 2.52s
# 100:	learn: 0.3205916	total: 283ms	remaining: 2.52s
# 101:	learn: 0.3198480	total: 285ms	remaining: 2.51s
# 102:	learn: 0.3189198	total: 291ms	remaining: 2.53s
# 103:	learn: 0.3183726	total: 295ms	remaining: 2.54s
# 104:	learn: 0.3176359	total: 298ms	remaining: 2.54s
# 105:	learn: 0.3169217	total: 300ms	remaining: 2.53s
# 106:	learn: 0.3156537	total: 303ms	remaining: 2.52s
# 107:	learn: 0.3150081	total: 305ms	remaining: 2.52s
# 108:	learn: 0.3142341	total: 307ms	remaining: 2.51s
# 109:	learn: 0.3132925	total: 310ms	remaining: 2.51s
# 110:	learn: 0.3125350	total: 312ms	remaining: 2.5s
# 111:	learn: 0.3115040	total: 326ms	remaining: 2.59s
# 112:	learn: 0.3103355	total: 330ms	remaining: 2.59s
# 113:	learn: 0.3097897	total: 333ms	remaining: 2.59s
# 114:	learn: 0.3090357	total: 340ms	remaining: 2.62s
# 115:	learn: 0.3085911	total: 349ms	remaining: 2.66s
# 116:	learn: 0.3076345	total: 353ms	remaining: 2.66s
# 117:	learn: 0.3067956	total: 357ms	remaining: 2.67s
# 118:	learn: 0.3060510	total: 366ms	remaining: 2.71s
# 119:	learn: 0.3053071	total: 369ms	remaining: 2.71s
# 120:	learn: 0.3044034	total: 376ms	remaining: 2.73s
# 121:	learn: 0.3036697	total: 383ms	remaining: 2.75s
# 122:	learn: 0.3030183	total: 385ms	remaining: 2.75s
# 123:	learn: 0.3023789	total: 388ms	remaining: 2.74s
# 124:	learn: 0.3019958	total: 390ms	remaining: 2.73s
# 125:	learn: 0.3014035	total: 393ms	remaining: 2.72s
# 126:	learn: 0.3008656	total: 395ms	remaining: 2.71s
# 127:	learn: 0.3001720	total: 398ms	remaining: 2.71s
# 128:	learn: 0.2994190	total: 400ms	remaining: 2.7s
# 129:	learn: 0.2989820	total: 403ms	remaining: 2.69s
# 130:	learn: 0.2984394	total: 405ms	remaining: 2.69s
# 131:	learn: 0.2978397	total: 407ms	remaining: 2.68s
# 132:	learn: 0.2973544	total: 410ms	remaining: 2.67s
# 133:	learn: 0.2966914	total: 413ms	remaining: 2.67s
# 134:	learn: 0.2957905	total: 415ms	remaining: 2.66s
# 135:	learn: 0.2952331	total: 418ms	remaining: 2.65s
# 136:	learn: 0.2945573	total: 420ms	remaining: 2.65s
# 137:	learn: 0.2935721	total: 422ms	remaining: 2.64s
# 138:	learn: 0.2928789	total: 425ms	remaining: 2.63s
# 139:	learn: 0.2921652	total: 428ms	remaining: 2.63s
# 140:	learn: 0.2915983	total: 430ms	remaining: 2.62s
# 141:	learn: 0.2909970	total: 433ms	remaining: 2.62s
# 142:	learn: 0.2905804	total: 435ms	remaining: 2.61s
# 143:	learn: 0.2899665	total: 438ms	remaining: 2.6s
# 144:	learn: 0.2894699	total: 440ms	remaining: 2.6s
# 145:	learn: 0.2889061	total: 443ms	remaining: 2.59s
# 146:	learn: 0.2882533	total: 446ms	remaining: 2.58s
# 147:	learn: 0.2876951	total: 448ms	remaining: 2.58s
# 148:	learn: 0.2871466	total: 451ms	remaining: 2.58s
# 149:	learn: 0.2866978	total: 454ms	remaining: 2.57s
# 150:	learn: 0.2860945	total: 456ms	remaining: 2.56s
# 151:	learn: 0.2857953	total: 459ms	remaining: 2.56s
# 152:	learn: 0.2853056	total: 461ms	remaining: 2.55s
# 153:	learn: 0.2845707	total: 466ms	remaining: 2.56s
# 154:	learn: 0.2840348	total: 473ms	remaining: 2.58s
# 155:	learn: 0.2831355	total: 476ms	remaining: 2.58s
# 156:	learn: 0.2825506	total: 479ms	remaining: 2.57s
# 157:	learn: 0.2820630	total: 483ms	remaining: 2.57s
# 158:	learn: 0.2816742	total: 488ms	remaining: 2.58s
# 159:	learn: 0.2812124	total: 491ms	remaining: 2.58s
# 160:	learn: 0.2808182	total: 494ms	remaining: 2.57s
# 161:	learn: 0.2799832	total: 497ms	remaining: 2.57s
# 162:	learn: 0.2794527	total: 502ms	remaining: 2.58s
# 163:	learn: 0.2789966	total: 505ms	remaining: 2.57s
# 164:	learn: 0.2785628	total: 512ms	remaining: 2.59s
# 165:	learn: 0.2781464	total: 522ms	remaining: 2.62s
# 166:	learn: 0.2775098	total: 526ms	remaining: 2.62s
# 167:	learn: 0.2770946	total: 533ms	remaining: 2.64s
# 168:	learn: 0.2763807	total: 537ms	remaining: 2.64s
# 169:	learn: 0.2759787	total: 539ms	remaining: 2.63s
# 170:	learn: 0.2755527	total: 542ms	remaining: 2.63s
# 171:	learn: 0.2752096	total: 545ms	remaining: 2.62s
# 172:	learn: 0.2748439	total: 547ms	remaining: 2.62s
# 173:	learn: 0.2742556	total: 550ms	remaining: 2.61s
# 174:	learn: 0.2739034	total: 553ms	remaining: 2.61s
# 175:	learn: 0.2733404	total: 556ms	remaining: 2.6s
# 176:	learn: 0.2729487	total: 558ms	remaining: 2.6s
# 177:	learn: 0.2726393	total: 561ms	remaining: 2.59s
# 178:	learn: 0.2720540	total: 565ms	remaining: 2.59s
# 179:	learn: 0.2712916	total: 571ms	remaining: 2.6s
# 180:	learn: 0.2708255	total: 575ms	remaining: 2.6s
# 181:	learn: 0.2703174	total: 577ms	remaining: 2.59s
# 182:	learn: 0.2699314	total: 581ms	remaining: 2.6s
# 183:	learn: 0.2694867	total: 584ms	remaining: 2.59s
# 184:	learn: 0.2691967	total: 586ms	remaining: 2.58s
# 185:	learn: 0.2685723	total: 589ms	remaining: 2.58s
# 186:	learn: 0.2681938	total: 591ms	remaining: 2.57s
# 187:	learn: 0.2676516	total: 594ms	remaining: 2.56s
# 188:	learn: 0.2670395	total: 596ms	remaining: 2.56s
# 189:	learn: 0.2664828	total: 600ms	remaining: 2.56s
# 190:	learn: 0.2660787	total: 603ms	remaining: 2.56s
# 191:	learn: 0.2652063	total: 607ms	remaining: 2.55s
# 192:	learn: 0.2649396	total: 611ms	remaining: 2.55s
# 193:	learn: 0.2643218	total: 616ms	remaining: 2.56s
# 194:	learn: 0.2640050	total: 619ms	remaining: 2.56s
# 195:	learn: 0.2633090	total: 627ms	remaining: 2.57s
# 196:	learn: 0.2629520	total: 635ms	remaining: 2.59s
# 197:	learn: 0.2626002	total: 642ms	remaining: 2.6s
# 198:	learn: 0.2621539	total: 649ms	remaining: 2.61s
# 199:	learn: 0.2618948	total: 651ms	remaining: 2.6s
# 200:	learn: 0.2613393	total: 654ms	remaining: 2.6s
# 201:	learn: 0.2609907	total: 656ms	remaining: 2.59s
# 202:	learn: 0.2607328	total: 659ms	remaining: 2.59s
# 203:	learn: 0.2604948	total: 662ms	remaining: 2.58s
# 204:	learn: 0.2600014	total: 664ms	remaining: 2.58s
# 205:	learn: 0.2597316	total: 668ms	remaining: 2.57s
# 206:	learn: 0.2591932	total: 671ms	remaining: 2.57s
# 207:	learn: 0.2587548	total: 674ms	remaining: 2.56s
# 208:	learn: 0.2584725	total: 676ms	remaining: 2.56s
# 209:	learn: 0.2580971	total: 679ms	remaining: 2.55s
# 210:	learn: 0.2576400	total: 681ms	remaining: 2.55s
# 211:	learn: 0.2570242	total: 684ms	remaining: 2.54s
# 212:	learn: 0.2567413	total: 686ms	remaining: 2.54s
# 213:	learn: 0.2564182	total: 689ms	remaining: 2.53s
# 214:	learn: 0.2561159	total: 691ms	remaining: 2.52s
# 215:	learn: 0.2555717	total: 694ms	remaining: 2.52s
# 216:	learn: 0.2553265	total: 697ms	remaining: 2.51s
# 217:	learn: 0.2549824	total: 700ms	remaining: 2.51s
# 218:	learn: 0.2547096	total: 702ms	remaining: 2.5s
# 219:	learn: 0.2543128	total: 705ms	remaining: 2.5s
# 220:	learn: 0.2538482	total: 708ms	remaining: 2.49s
# 221:	learn: 0.2535509	total: 710ms	remaining: 2.49s
# 222:	learn: 0.2531652	total: 712ms	remaining: 2.48s
# 223:	learn: 0.2529411	total: 715ms	remaining: 2.48s
# 224:	learn: 0.2524920	total: 718ms	remaining: 2.47s
# 225:	learn: 0.2521186	total: 720ms	remaining: 2.47s
# 226:	learn: 0.2516857	total: 723ms	remaining: 2.46s
# 227:	learn: 0.2512482	total: 725ms	remaining: 2.45s
# 228:	learn: 0.2509831	total: 728ms	remaining: 2.45s
# 229:	learn: 0.2507359	total: 731ms	remaining: 2.44s
# 230:	learn: 0.2502879	total: 733ms	remaining: 2.44s
# 231:	learn: 0.2498860	total: 735ms	remaining: 2.43s
# 232:	learn: 0.2493870	total: 744ms	remaining: 2.45s
# 233:	learn: 0.2488617	total: 747ms	remaining: 2.44s
# 234:	learn: 0.2483881	total: 749ms	remaining: 2.44s
# 235:	learn: 0.2480888	total: 752ms	remaining: 2.43s
# 236:	learn: 0.2476464	total: 757ms	remaining: 2.44s
# 237:	learn: 0.2473905	total: 761ms	remaining: 2.44s
# 238:	learn: 0.2469654	total: 765ms	remaining: 2.44s
# 239:	learn: 0.2466032	total: 769ms	remaining: 2.44s
# 240:	learn: 0.2462426	total: 772ms	remaining: 2.43s
# 241:	learn: 0.2460156	total: 775ms	remaining: 2.43s
# 242:	learn: 0.2458341	total: 777ms	remaining: 2.42s
# 243:	learn: 0.2455845	total: 779ms	remaining: 2.41s
# 244:	learn: 0.2451007	total: 782ms	remaining: 2.41s
# 245:	learn: 0.2445712	total: 785ms	remaining: 2.41s
# 246:	learn: 0.2442395	total: 788ms	remaining: 2.4s
# 247:	learn: 0.2439007	total: 792ms	remaining: 2.4s
# 248:	learn: 0.2436024	total: 795ms	remaining: 2.4s
# 249:	learn: 0.2429075	total: 797ms	remaining: 2.39s
# 250:	learn: 0.2424498	total: 800ms	remaining: 2.39s
# 251:	learn: 0.2421069	total: 802ms	remaining: 2.38s
# 252:	learn: 0.2415736	total: 805ms	remaining: 2.38s
# 253:	learn: 0.2413209	total: 808ms	remaining: 2.37s
# 254:	learn: 0.2411130	total: 810ms	remaining: 2.37s
# 255:	learn: 0.2407019	total: 814ms	remaining: 2.36s
# 256:	learn: 0.2404545	total: 816ms	remaining: 2.36s
# 257:	learn: 0.2400631	total: 819ms	remaining: 2.35s
# 258:	learn: 0.2397547	total: 821ms	remaining: 2.35s
# 259:	learn: 0.2394537	total: 824ms	remaining: 2.35s
# 260:	learn: 0.2390679	total: 827ms	remaining: 2.34s
# 261:	learn: 0.2387180	total: 829ms	remaining: 2.33s
# 262:	learn: 0.2384260	total: 831ms	remaining: 2.33s
# 263:	learn: 0.2379739	total: 834ms	remaining: 2.32s
# 264:	learn: 0.2376212	total: 836ms	remaining: 2.32s
# 265:	learn: 0.2373858	total: 839ms	remaining: 2.31s
# 266:	learn: 0.2371411	total: 841ms	remaining: 2.31s
# 267:	learn: 0.2366348	total: 844ms	remaining: 2.3s
# 268:	learn: 0.2362887	total: 846ms	remaining: 2.3s
# 269:	learn: 0.2358005	total: 849ms	remaining: 2.29s
# 270:	learn: 0.2353558	total: 852ms	remaining: 2.29s
# 271:	learn: 0.2350197	total: 856ms	remaining: 2.29s
# 272:	learn: 0.2347463	total: 863ms	remaining: 2.3s
# 273:	learn: 0.2341804	total: 866ms	remaining: 2.29s
# 274:	learn: 0.2339414	total: 868ms	remaining: 2.29s
# 275:	learn: 0.2336949	total: 871ms	remaining: 2.28s
# 276:	learn: 0.2334401	total: 873ms	remaining: 2.28s
# 277:	learn: 0.2332778	total: 876ms	remaining: 2.27s
# 278:	learn: 0.2330069	total: 881ms	remaining: 2.28s
# 279:	learn: 0.2326264	total: 884ms	remaining: 2.27s
# 280:	learn: 0.2322255	total: 886ms	remaining: 2.27s
# 281:	learn: 0.2319748	total: 889ms	remaining: 2.26s
# 282:	learn: 0.2317733	total: 891ms	remaining: 2.26s
# 283:	learn: 0.2314353	total: 893ms	remaining: 2.25s
# 284:	learn: 0.2311054	total: 896ms	remaining: 2.25s
# 285:	learn: 0.2308400	total: 899ms	remaining: 2.24s
# 286:	learn: 0.2304586	total: 901ms	remaining: 2.24s
# 287:	learn: 0.2301873	total: 904ms	remaining: 2.23s
# 288:	learn: 0.2301021	total: 906ms	remaining: 2.23s
# 289:	learn: 0.2298330	total: 909ms	remaining: 2.23s
# 290:	learn: 0.2295858	total: 912ms	remaining: 2.22s
# 291:	learn: 0.2293644	total: 914ms	remaining: 2.22s
# 292:	learn: 0.2290259	total: 917ms	remaining: 2.21s
# 293:	learn: 0.2287526	total: 922ms	remaining: 2.21s
# 294:	learn: 0.2282232	total: 925ms	remaining: 2.21s
# 295:	learn: 0.2280547	total: 928ms	remaining: 2.21s
# 296:	learn: 0.2275835	total: 931ms	remaining: 2.2s
# 297:	learn: 0.2271234	total: 934ms	remaining: 2.2s
# 298:	learn: 0.2269131	total: 937ms	remaining: 2.2s
# 299:	learn: 0.2265208	total: 940ms	remaining: 2.19s
# 300:	learn: 0.2263372	total: 942ms	remaining: 2.19s
# 301:	learn: 0.2261193	total: 944ms	remaining: 2.18s
# 302:	learn: 0.2259047	total: 948ms	remaining: 2.18s
# 303:	learn: 0.2257083	total: 952ms	remaining: 2.18s
# 304:	learn: 0.2255522	total: 957ms	remaining: 2.18s
# 305:	learn: 0.2253039	total: 960ms	remaining: 2.18s
# 306:	learn: 0.2249005	total: 963ms	remaining: 2.17s
# 307:	learn: 0.2246212	total: 967ms	remaining: 2.17s
# 308:	learn: 0.2242355	total: 970ms	remaining: 2.17s
# 309:	learn: 0.2239812	total: 972ms	remaining: 2.16s
# 310:	learn: 0.2237092	total: 975ms	remaining: 2.16s
# 311:	learn: 0.2234646	total: 977ms	remaining: 2.15s
# 312:	learn: 0.2232762	total: 980ms	remaining: 2.15s
# 313:	learn: 0.2230045	total: 982ms	remaining: 2.15s
# 314:	learn: 0.2227982	total: 985ms	remaining: 2.14s
# 315:	learn: 0.2225312	total: 987ms	remaining: 2.14s
# 316:	learn: 0.2222468	total: 989ms	remaining: 2.13s
# 317:	learn: 0.2219036	total: 992ms	remaining: 2.13s
# 318:	learn: 0.2217700	total: 994ms	remaining: 2.12s
# 319:	learn: 0.2214272	total: 997ms	remaining: 2.12s
# 320:	learn: 0.2212904	total: 999ms	remaining: 2.11s
# 321:	learn: 0.2210898	total: 1s	remaining: 2.11s
# 322:	learn: 0.2208175	total: 1s	remaining: 2.1s
# 323:	learn: 0.2206158	total: 1.01s	remaining: 2.1s
# 324:	learn: 0.2200190	total: 1.01s	remaining: 2.1s
# 325:	learn: 0.2197555	total: 1.01s	remaining: 2.1s
# 326:	learn: 0.2195717	total: 1.02s	remaining: 2.09s
# 327:	learn: 0.2193770	total: 1.02s	remaining: 2.09s
# 328:	learn: 0.2192414	total: 1.02s	remaining: 2.09s
# 329:	learn: 0.2190298	total: 1.02s	remaining: 2.08s
# 330:	learn: 0.2187446	total: 1.03s	remaining: 2.08s
# 331:	learn: 0.2183402	total: 1.03s	remaining: 2.07s
# 332:	learn: 0.2179928	total: 1.03s	remaining: 2.07s
# 333:	learn: 0.2176812	total: 1.03s	remaining: 2.06s
# 334:	learn: 0.2173949	total: 1.04s	remaining: 2.06s
# 335:	learn: 0.2169656	total: 1.04s	remaining: 2.06s
# 336:	learn: 0.2167798	total: 1.06s	remaining: 2.08s
# 337:	learn: 0.2165488	total: 1.06s	remaining: 2.08s
# 338:	learn: 0.2162472	total: 1.06s	remaining: 2.07s
# 339:	learn: 0.2158941	total: 1.07s	remaining: 2.07s
# 340:	learn: 0.2155852	total: 1.07s	remaining: 2.06s
# 341:	learn: 0.2153047	total: 1.07s	remaining: 2.06s
# 342:	learn: 0.2150297	total: 1.07s	remaining: 2.06s
# 343:	learn: 0.2147416	total: 1.07s	remaining: 2.05s
# 344:	learn: 0.2145352	total: 1.08s	remaining: 2.05s
# 345:	learn: 0.2143369	total: 1.08s	remaining: 2.04s
# 346:	learn: 0.2141846	total: 1.08s	remaining: 2.04s
# 347:	learn: 0.2138998	total: 1.09s	remaining: 2.04s
# 348:	learn: 0.2136592	total: 1.09s	remaining: 2.03s
# 349:	learn: 0.2133852	total: 1.09s	remaining: 2.03s
# 350:	learn: 0.2130636	total: 1.09s	remaining: 2.02s
# 351:	learn: 0.2128273	total: 1.1s	remaining: 2.02s
# 352:	learn: 0.2125594	total: 1.1s	remaining: 2.02s
# 353:	learn: 0.2124136	total: 1.1s	remaining: 2.01s
# 354:	learn: 0.2122072	total: 1.1s	remaining: 2.01s
# 355:	learn: 0.2119613	total: 1.11s	remaining: 2s
# 356:	learn: 0.2115653	total: 1.11s	remaining: 2s
# 357:	learn: 0.2113895	total: 1.11s	remaining: 2s
# 358:	learn: 0.2109039	total: 1.11s	remaining: 1.99s
# 359:	learn: 0.2107266	total: 1.12s	remaining: 1.99s
# 360:	learn: 0.2104039	total: 1.12s	remaining: 1.98s
# 361:	learn: 0.2102535	total: 1.12s	remaining: 1.98s
# 362:	learn: 0.2100442	total: 1.13s	remaining: 1.98s
# 363:	learn: 0.2098550	total: 1.13s	remaining: 1.97s
# 364:	learn: 0.2096354	total: 1.13s	remaining: 1.97s
# 365:	learn: 0.2093950	total: 1.13s	remaining: 1.96s
# 366:	learn: 0.2092230	total: 1.14s	remaining: 1.96s
# 367:	learn: 0.2088733	total: 1.14s	remaining: 1.96s
# 368:	learn: 0.2086848	total: 1.16s	remaining: 1.98s
# 369:	learn: 0.2084182	total: 1.16s	remaining: 1.98s
# 370:	learn: 0.2081484	total: 1.16s	remaining: 1.97s
# 371:	learn: 0.2078586	total: 1.17s	remaining: 1.97s
# 372:	learn: 0.2076680	total: 1.17s	remaining: 1.96s
# 373:	learn: 0.2074105	total: 1.17s	remaining: 1.96s
# 374:	learn: 0.2072533	total: 1.17s	remaining: 1.96s
# 375:	learn: 0.2070111	total: 1.18s	remaining: 1.96s
# 376:	learn: 0.2067481	total: 1.19s	remaining: 1.96s
# 377:	learn: 0.2063842	total: 1.19s	remaining: 1.96s
# 378:	learn: 0.2062637	total: 1.19s	remaining: 1.95s
# 379:	learn: 0.2060581	total: 1.19s	remaining: 1.95s
# 380:	learn: 0.2057856	total: 1.2s	remaining: 1.95s
# 381:	learn: 0.2056021	total: 1.2s	remaining: 1.94s
# 382:	learn: 0.2054217	total: 1.2s	remaining: 1.94s
# 383:	learn: 0.2052322	total: 1.21s	remaining: 1.93s
# 384:	learn: 0.2050503	total: 1.21s	remaining: 1.93s
# 385:	learn: 0.2048578	total: 1.21s	remaining: 1.93s
# 386:	learn: 0.2046895	total: 1.21s	remaining: 1.92s
# 387:	learn: 0.2043554	total: 1.22s	remaining: 1.92s
# 388:	learn: 0.2040346	total: 1.22s	remaining: 1.91s
# 389:	learn: 0.2037694	total: 1.22s	remaining: 1.91s
# 390:	learn: 0.2036223	total: 1.22s	remaining: 1.9s
# 391:	learn: 0.2034170	total: 1.22s	remaining: 1.9s
# 392:	learn: 0.2031204	total: 1.23s	remaining: 1.9s
# 393:	learn: 0.2030056	total: 1.23s	remaining: 1.89s
# 394:	learn: 0.2028451	total: 1.23s	remaining: 1.89s
# 395:	learn: 0.2025876	total: 1.23s	remaining: 1.88s
# 396:	learn: 0.2024551	total: 1.24s	remaining: 1.88s
# 397:	learn: 0.2022641	total: 1.25s	remaining: 1.89s
# 398:	learn: 0.2021046	total: 1.25s	remaining: 1.88s
# 399:	learn: 0.2019188	total: 1.25s	remaining: 1.88s
# 400:	learn: 0.2016473	total: 1.25s	remaining: 1.87s
# 401:	learn: 0.2015109	total: 1.26s	remaining: 1.87s
# 402:	learn: 0.2013365	total: 1.26s	remaining: 1.86s
# 403:	learn: 0.2011733	total: 1.26s	remaining: 1.86s
# 404:	learn: 0.2009090	total: 1.26s	remaining: 1.86s
# 405:	learn: 0.2006308	total: 1.27s	remaining: 1.85s
# 406:	learn: 0.2003334	total: 1.27s	remaining: 1.85s
# 407:	learn: 0.2002202	total: 1.27s	remaining: 1.85s
# 408:	learn: 0.2000164	total: 1.27s	remaining: 1.84s
# 409:	learn: 0.1997568	total: 1.28s	remaining: 1.84s
# 410:	learn: 0.1995444	total: 1.28s	remaining: 1.83s
# 411:	learn: 0.1994152	total: 1.28s	remaining: 1.83s
# 412:	learn: 0.1992141	total: 1.29s	remaining: 1.83s
# 413:	learn: 0.1989840	total: 1.29s	remaining: 1.83s
# 414:	learn: 0.1988091	total: 1.3s	remaining: 1.83s
# 415:	learn: 0.1985339	total: 1.3s	remaining: 1.82s
# 416:	learn: 0.1982024	total: 1.3s	remaining: 1.82s
# 417:	learn: 0.1980353	total: 1.3s	remaining: 1.81s
# 418:	learn: 0.1978959	total: 1.31s	remaining: 1.81s
# 419:	learn: 0.1977067	total: 1.31s	remaining: 1.81s
# 420:	learn: 0.1975103	total: 1.31s	remaining: 1.8s
# 421:	learn: 0.1972899	total: 1.31s	remaining: 1.8s
# 422:	learn: 0.1971499	total: 1.32s	remaining: 1.8s
# 423:	learn: 0.1969936	total: 1.32s	remaining: 1.79s
# 424:	learn: 0.1967836	total: 1.32s	remaining: 1.79s
# 425:	learn: 0.1965553	total: 1.32s	remaining: 1.78s
# 426:	learn: 0.1963808	total: 1.33s	remaining: 1.78s
# 427:	learn: 0.1961375	total: 1.33s	remaining: 1.78s
# 428:	learn: 0.1959756	total: 1.34s	remaining: 1.78s
# 429:	learn: 0.1957266	total: 1.34s	remaining: 1.78s
# 430:	learn: 0.1954724	total: 1.35s	remaining: 1.78s
# 431:	learn: 0.1953558	total: 1.35s	remaining: 1.78s
# 432:	learn: 0.1952535	total: 1.36s	remaining: 1.77s
# 433:	learn: 0.1949458	total: 1.36s	remaining: 1.77s
# 434:	learn: 0.1946669	total: 1.36s	remaining: 1.77s
# 435:	learn: 0.1944845	total: 1.36s	remaining: 1.76s
# 436:	learn: 0.1943564	total: 1.37s	remaining: 1.76s
# 437:	learn: 0.1941881	total: 1.37s	remaining: 1.75s
# 438:	learn: 0.1939565	total: 1.37s	remaining: 1.75s
# 439:	learn: 0.1936811	total: 1.37s	remaining: 1.75s
# 440:	learn: 0.1935320	total: 1.38s	remaining: 1.74s
# 441:	learn: 0.1932841	total: 1.38s	remaining: 1.74s
# 442:	learn: 0.1931535	total: 1.38s	remaining: 1.74s
# 443:	learn: 0.1929324	total: 1.38s	remaining: 1.73s
# 444:	learn: 0.1927663	total: 1.39s	remaining: 1.73s
# 445:	learn: 0.1925383	total: 1.39s	remaining: 1.72s
# 446:	learn: 0.1922784	total: 1.39s	remaining: 1.72s
# 447:	learn: 0.1919811	total: 1.39s	remaining: 1.72s
# 448:	learn: 0.1917645	total: 1.4s	remaining: 1.71s
# 449:	learn: 0.1915775	total: 1.4s	remaining: 1.71s
# 450:	learn: 0.1913879	total: 1.4s	remaining: 1.71s
# 451:	learn: 0.1910919	total: 1.4s	remaining: 1.7s
# 452:	learn: 0.1908565	total: 1.41s	remaining: 1.7s
# 453:	learn: 0.1906354	total: 1.41s	remaining: 1.7s
# 454:	learn: 0.1904746	total: 1.41s	remaining: 1.69s
# 455:	learn: 0.1902280	total: 1.42s	remaining: 1.7s
# 456:	learn: 0.1900170	total: 1.43s	remaining: 1.69s
# 457:	learn: 0.1899101	total: 1.43s	remaining: 1.69s
# 458:	learn: 0.1897521	total: 1.43s	remaining: 1.69s
# 459:	learn: 0.1894141	total: 1.44s	remaining: 1.69s
# 460:	learn: 0.1891671	total: 1.44s	remaining: 1.69s
# 461:	learn: 0.1889431	total: 1.45s	remaining: 1.68s
# 462:	learn: 0.1887774	total: 1.45s	remaining: 1.68s
# 463:	learn: 0.1886318	total: 1.45s	remaining: 1.68s
# 464:	learn: 0.1884805	total: 1.45s	remaining: 1.67s
# 465:	learn: 0.1883576	total: 1.46s	remaining: 1.67s
# 466:	learn: 0.1882141	total: 1.46s	remaining: 1.67s
# 467:	learn: 0.1879489	total: 1.46s	remaining: 1.66s
# 468:	learn: 0.1877098	total: 1.47s	remaining: 1.66s
# 469:	learn: 0.1875202	total: 1.47s	remaining: 1.66s
# 470:	learn: 0.1873404	total: 1.48s	remaining: 1.66s
# 471:	learn: 0.1871264	total: 1.48s	remaining: 1.66s
# 472:	learn: 0.1867999	total: 1.49s	remaining: 1.66s
# 473:	learn: 0.1865847	total: 1.49s	remaining: 1.65s
# 474:	learn: 0.1863626	total: 1.49s	remaining: 1.65s
# 475:	learn: 0.1861082	total: 1.49s	remaining: 1.65s
# 476:	learn: 0.1859873	total: 1.5s	remaining: 1.64s
# 477:	learn: 0.1858346	total: 1.5s	remaining: 1.64s
# 478:	learn: 0.1856349	total: 1.5s	remaining: 1.64s
# 479:	learn: 0.1853977	total: 1.5s	remaining: 1.63s
# 480:	learn: 0.1852099	total: 1.51s	remaining: 1.63s
# 481:	learn: 0.1849766	total: 1.51s	remaining: 1.62s
# 482:	learn: 0.1846498	total: 1.51s	remaining: 1.62s
# 483:	learn: 0.1844989	total: 1.51s	remaining: 1.61s
# 484:	learn: 0.1844162	total: 1.52s	remaining: 1.61s
# 485:	learn: 0.1842233	total: 1.52s	remaining: 1.61s
# 486:	learn: 0.1840009	total: 1.52s	remaining: 1.6s
# 487:	learn: 0.1838481	total: 1.52s	remaining: 1.6s
# 488:	learn: 0.1836834	total: 1.53s	remaining: 1.6s
# 489:	learn: 0.1835038	total: 1.53s	remaining: 1.6s
# 490:	learn: 0.1834216	total: 1.54s	remaining: 1.59s
# 491:	learn: 0.1831112	total: 1.54s	remaining: 1.59s
# 492:	learn: 0.1830296	total: 1.54s	remaining: 1.59s
# 493:	learn: 0.1828990	total: 1.54s	remaining: 1.58s
# 494:	learn: 0.1826704	total: 1.55s	remaining: 1.58s
# 495:	learn: 0.1824459	total: 1.55s	remaining: 1.58s
# 496:	learn: 0.1822572	total: 1.55s	remaining: 1.57s
# 497:	learn: 0.1820887	total: 1.57s	remaining: 1.58s
# 498:	learn: 0.1818105	total: 1.57s	remaining: 1.58s
# 499:	learn: 0.1815507	total: 1.57s	remaining: 1.57s
# 500:	learn: 0.1813432	total: 1.58s	remaining: 1.57s
# 501:	learn: 0.1811187	total: 1.58s	remaining: 1.57s
# 502:	learn: 0.1809791	total: 1.59s	remaining: 1.57s
# 503:	learn: 0.1807559	total: 1.59s	remaining: 1.56s
# 504:	learn: 0.1805962	total: 1.59s	remaining: 1.56s
# 505:	learn: 0.1804350	total: 1.59s	remaining: 1.56s
# 506:	learn: 0.1802947	total: 1.6s	remaining: 1.55s
# 507:	learn: 0.1801458	total: 1.6s	remaining: 1.55s
# 508:	learn: 0.1799179	total: 1.6s	remaining: 1.55s
# 509:	learn: 0.1796683	total: 1.6s	remaining: 1.54s
# 510:	learn: 0.1794806	total: 1.61s	remaining: 1.54s
# 511:	learn: 0.1792796	total: 1.61s	remaining: 1.53s
# 512:	learn: 0.1791539	total: 1.61s	remaining: 1.53s
# 513:	learn: 0.1789482	total: 1.61s	remaining: 1.53s
# 514:	learn: 0.1788777	total: 1.62s	remaining: 1.52s
# 515:	learn: 0.1787808	total: 1.62s	remaining: 1.52s
# 516:	learn: 0.1785967	total: 1.63s	remaining: 1.52s
# 517:	learn: 0.1783648	total: 1.63s	remaining: 1.52s
# 518:	learn: 0.1781588	total: 1.64s	remaining: 1.52s
# 519:	learn: 0.1779841	total: 1.64s	remaining: 1.51s
# 520:	learn: 0.1778231	total: 1.64s	remaining: 1.51s
# 521:	learn: 0.1775760	total: 1.65s	remaining: 1.51s
# 522:	learn: 0.1774460	total: 1.65s	remaining: 1.5s
# 523:	learn: 0.1772060	total: 1.65s	remaining: 1.5s
# 524:	learn: 0.1770113	total: 1.65s	remaining: 1.5s
# 525:	learn: 0.1768002	total: 1.65s	remaining: 1.49s
# 526:	learn: 0.1766468	total: 1.66s	remaining: 1.49s
# 527:	learn: 0.1765844	total: 1.66s	remaining: 1.48s
# 528:	learn: 0.1764007	total: 1.66s	remaining: 1.48s
# 529:	learn: 0.1762426	total: 1.66s	remaining: 1.48s
# 530:	learn: 0.1760646	total: 1.67s	remaining: 1.47s
# 531:	learn: 0.1758121	total: 1.67s	remaining: 1.47s
# 532:	learn: 0.1756829	total: 1.67s	remaining: 1.46s
# 533:	learn: 0.1755383	total: 1.67s	remaining: 1.46s
# 534:	learn: 0.1752735	total: 1.68s	remaining: 1.46s
# 535:	learn: 0.1750945	total: 1.68s	remaining: 1.45s
# 536:	learn: 0.1748762	total: 1.68s	remaining: 1.45s
# 537:	learn: 0.1747486	total: 1.68s	remaining: 1.45s
# 538:	learn: 0.1745863	total: 1.69s	remaining: 1.44s
# 539:	learn: 0.1744574	total: 1.69s	remaining: 1.44s
# 540:	learn: 0.1743073	total: 1.69s	remaining: 1.44s
# 541:	learn: 0.1741274	total: 1.69s	remaining: 1.43s
# 542:	learn: 0.1740094	total: 1.7s	remaining: 1.43s
# 543:	learn: 0.1738564	total: 1.7s	remaining: 1.42s
# 544:	learn: 0.1737328	total: 1.7s	remaining: 1.42s
# 545:	learn: 0.1735014	total: 1.7s	remaining: 1.42s
# 546:	learn: 0.1733653	total: 1.71s	remaining: 1.41s
# 547:	learn: 0.1731006	total: 1.71s	remaining: 1.41s
# 548:	learn: 0.1729068	total: 1.72s	remaining: 1.41s
# 549:	learn: 0.1727232	total: 1.72s	remaining: 1.41s
# 550:	learn: 0.1725456	total: 1.73s	remaining: 1.41s
# 551:	learn: 0.1723188	total: 1.74s	remaining: 1.41s
# 552:	learn: 0.1721301	total: 1.74s	remaining: 1.4s
# 553:	learn: 0.1718860	total: 1.74s	remaining: 1.4s
# 554:	learn: 0.1717365	total: 1.74s	remaining: 1.4s
# 555:	learn: 0.1716259	total: 1.75s	remaining: 1.39s
# 556:	learn: 0.1714599	total: 1.75s	remaining: 1.39s
# 557:	learn: 0.1712197	total: 1.75s	remaining: 1.39s
# 558:	learn: 0.1710770	total: 1.75s	remaining: 1.38s
# 559:	learn: 0.1709128	total: 1.75s	remaining: 1.38s
# 560:	learn: 0.1707776	total: 1.76s	remaining: 1.38s
# 561:	learn: 0.1706301	total: 1.76s	remaining: 1.37s
# 562:	learn: 0.1704766	total: 1.76s	remaining: 1.37s
# 563:	learn: 0.1702742	total: 1.76s	remaining: 1.36s
# 564:	learn: 0.1701323	total: 1.77s	remaining: 1.36s
# 565:	learn: 0.1699420	total: 1.77s	remaining: 1.36s
# 566:	learn: 0.1698053	total: 1.77s	remaining: 1.35s
# 567:	learn: 0.1696926	total: 1.77s	remaining: 1.35s
# 568:	learn: 0.1695924	total: 1.78s	remaining: 1.35s
# 569:	learn: 0.1694760	total: 1.78s	remaining: 1.34s
# 570:	learn: 0.1692263	total: 1.78s	remaining: 1.34s
# 571:	learn: 0.1691086	total: 1.78s	remaining: 1.33s
# 572:	learn: 0.1689614	total: 1.79s	remaining: 1.33s
# 573:	learn: 0.1687863	total: 1.79s	remaining: 1.33s
# 574:	learn: 0.1686248	total: 1.79s	remaining: 1.32s
# 575:	learn: 0.1684870	total: 1.79s	remaining: 1.32s
# 576:	learn: 0.1683516	total: 1.8s	remaining: 1.32s
# 577:	learn: 0.1681526	total: 1.8s	remaining: 1.31s
# 578:	learn: 0.1680596	total: 1.8s	remaining: 1.31s
# 579:	learn: 0.1679032	total: 1.8s	remaining: 1.31s
# 580:	learn: 0.1676819	total: 1.81s	remaining: 1.3s
# 581:	learn: 0.1674769	total: 1.81s	remaining: 1.3s
# 582:	learn: 0.1672971	total: 1.82s	remaining: 1.3s
# 583:	learn: 0.1670367	total: 1.82s	remaining: 1.3s
# 584:	learn: 0.1669282	total: 1.82s	remaining: 1.29s
# 585:	learn: 0.1667727	total: 1.82s	remaining: 1.29s
# 586:	learn: 0.1666315	total: 1.83s	remaining: 1.29s
# 587:	learn: 0.1664350	total: 1.83s	remaining: 1.28s
# 588:	learn: 0.1663282	total: 1.84s	remaining: 1.28s
# 589:	learn: 0.1661498	total: 1.84s	remaining: 1.28s
# 590:	learn: 0.1660313	total: 1.84s	remaining: 1.27s
# 591:	learn: 0.1658567	total: 1.84s	remaining: 1.27s
# 592:	learn: 0.1657753	total: 1.85s	remaining: 1.27s
# 593:	learn: 0.1655540	total: 1.85s	remaining: 1.26s
# 594:	learn: 0.1653320	total: 1.85s	remaining: 1.26s
# 595:	learn: 0.1651229	total: 1.85s	remaining: 1.26s
# 596:	learn: 0.1649752	total: 1.86s	remaining: 1.25s
# 597:	learn: 0.1648831	total: 1.86s	remaining: 1.25s
# 598:	learn: 0.1647373	total: 1.86s	remaining: 1.25s
# 599:	learn: 0.1646301	total: 1.86s	remaining: 1.24s
# 600:	learn: 0.1645259	total: 1.87s	remaining: 1.24s
# 601:	learn: 0.1642978	total: 1.87s	remaining: 1.24s
# 602:	learn: 0.1640921	total: 1.88s	remaining: 1.23s
# 603:	learn: 0.1639211	total: 1.88s	remaining: 1.23s
# 604:	learn: 0.1637480	total: 1.88s	remaining: 1.23s
# 605:	learn: 0.1636662	total: 1.88s	remaining: 1.22s
# 606:	learn: 0.1635131	total: 1.89s	remaining: 1.22s
# 607:	learn: 0.1632839	total: 1.89s	remaining: 1.22s
# 608:	learn: 0.1631467	total: 1.89s	remaining: 1.21s
# 609:	learn: 0.1630156	total: 1.89s	remaining: 1.21s
# 610:	learn: 0.1628963	total: 1.9s	remaining: 1.21s
# 611:	learn: 0.1628052	total: 1.9s	remaining: 1.2s
# 612:	learn: 0.1626199	total: 1.9s	remaining: 1.2s
# 613:	learn: 0.1624878	total: 1.9s	remaining: 1.2s
# 614:	learn: 0.1622590	total: 1.91s	remaining: 1.19s
# 615:	learn: 0.1620765	total: 1.91s	remaining: 1.19s
# 616:	learn: 0.1619147	total: 1.91s	remaining: 1.19s
# 617:	learn: 0.1617604	total: 1.92s	remaining: 1.19s
# 618:	learn: 0.1616577	total: 1.92s	remaining: 1.18s
# 619:	learn: 0.1614615	total: 1.92s	remaining: 1.18s
# 620:	learn: 0.1613444	total: 1.92s	remaining: 1.17s
# 621:	learn: 0.1612430	total: 1.93s	remaining: 1.17s
# 622:	learn: 0.1610032	total: 1.93s	remaining: 1.17s
# 623:	learn: 0.1608407	total: 1.93s	remaining: 1.16s
# 624:	learn: 0.1606120	total: 1.93s	remaining: 1.16s
# 625:	learn: 0.1605167	total: 1.94s	remaining: 1.16s
# 626:	learn: 0.1603380	total: 1.94s	remaining: 1.15s
# 627:	learn: 0.1602563	total: 1.94s	remaining: 1.15s
# 628:	learn: 0.1601585	total: 1.94s	remaining: 1.15s
# 629:	learn: 0.1601004	total: 1.95s	remaining: 1.14s
# 630:	learn: 0.1599692	total: 1.95s	remaining: 1.14s
# 631:	learn: 0.1598258	total: 1.95s	remaining: 1.14s
# 632:	learn: 0.1597438	total: 1.95s	remaining: 1.13s
# 633:	learn: 0.1596394	total: 1.96s	remaining: 1.13s
# 634:	learn: 0.1595327	total: 1.96s	remaining: 1.13s
# 635:	learn: 0.1593393	total: 1.96s	remaining: 1.12s
# 636:	learn: 0.1591871	total: 1.96s	remaining: 1.12s
# 637:	learn: 0.1590941	total: 1.97s	remaining: 1.12s
# 638:	learn: 0.1590243	total: 1.97s	remaining: 1.11s
# 639:	learn: 0.1588367	total: 1.97s	remaining: 1.11s
# 640:	learn: 0.1586863	total: 1.97s	remaining: 1.1s
# 641:	learn: 0.1584919	total: 1.98s	remaining: 1.1s
# 642:	learn: 0.1583116	total: 1.98s	remaining: 1.1s
# 643:	learn: 0.1580947	total: 1.98s	remaining: 1.1s
# 644:	learn: 0.1580104	total: 1.99s	remaining: 1.09s
# 645:	learn: 0.1578707	total: 1.99s	remaining: 1.09s
# 646:	learn: 0.1577441	total: 1.99s	remaining: 1.09s
# 647:	learn: 0.1575720	total: 2s	remaining: 1.09s
# 648:	learn: 0.1574629	total: 2s	remaining: 1.08s
# 649:	learn: 0.1572749	total: 2.01s	remaining: 1.08s
# 650:	learn: 0.1571200	total: 2.01s	remaining: 1.08s
# 651:	learn: 0.1569883	total: 2.02s	remaining: 1.07s
# 652:	learn: 0.1568835	total: 2.02s	remaining: 1.07s
# 653:	learn: 0.1567149	total: 2.02s	remaining: 1.07s
# 654:	learn: 0.1565087	total: 2.03s	remaining: 1.07s
# 655:	learn: 0.1563570	total: 2.04s	remaining: 1.07s
# 656:	learn: 0.1561353	total: 2.04s	remaining: 1.07s
# 657:	learn: 0.1560208	total: 2.05s	remaining: 1.06s
# 658:	learn: 0.1558435	total: 2.05s	remaining: 1.06s
# 659:	learn: 0.1557424	total: 2.06s	remaining: 1.06s
# 660:	learn: 0.1555866	total: 2.06s	remaining: 1.06s
# 661:	learn: 0.1554802	total: 2.06s	remaining: 1.05s
# 662:	learn: 0.1552599	total: 2.06s	remaining: 1.05s
# 663:	learn: 0.1551098	total: 2.07s	remaining: 1.04s
# 664:	learn: 0.1550011	total: 2.07s	remaining: 1.04s
# 665:	learn: 0.1548824	total: 2.07s	remaining: 1.04s
# 666:	learn: 0.1547086	total: 2.07s	remaining: 1.03s
# 667:	learn: 0.1545817	total: 2.07s	remaining: 1.03s
# 668:	learn: 0.1544029	total: 2.08s	remaining: 1.03s
# 669:	learn: 0.1542115	total: 2.08s	remaining: 1.02s
# 670:	learn: 0.1541253	total: 2.08s	remaining: 1.02s
# 671:	learn: 0.1539277	total: 2.08s	remaining: 1.02s
# 672:	learn: 0.1537771	total: 2.09s	remaining: 1.01s
# 673:	learn: 0.1536687	total: 2.09s	remaining: 1.01s
# 674:	learn: 0.1535371	total: 2.09s	remaining: 1.01s
# 675:	learn: 0.1534020	total: 2.09s	remaining: 1s
# 676:	learn: 0.1532516	total: 2.1s	remaining: 1s
# 677:	learn: 0.1530628	total: 2.1s	remaining: 999ms
# 678:	learn: 0.1529263	total: 2.11s	remaining: 997ms
# 679:	learn: 0.1527953	total: 2.11s	remaining: 993ms
# 680:	learn: 0.1526800	total: 2.11s	remaining: 990ms
# 681:	learn: 0.1525155	total: 2.12s	remaining: 986ms
# 682:	learn: 0.1523693	total: 2.12s	remaining: 983ms
# 683:	learn: 0.1522403	total: 2.12s	remaining: 980ms
# 684:	learn: 0.1521409	total: 2.12s	remaining: 977ms
# 685:	learn: 0.1519753	total: 2.13s	remaining: 974ms
# 686:	learn: 0.1518183	total: 2.13s	remaining: 971ms
# 687:	learn: 0.1516988	total: 2.13s	remaining: 967ms
# 688:	learn: 0.1515500	total: 2.13s	remaining: 964ms
# 689:	learn: 0.1514532	total: 2.14s	remaining: 960ms
# 690:	learn: 0.1513503	total: 2.14s	remaining: 957ms
# 691:	learn: 0.1512083	total: 2.14s	remaining: 954ms
# 692:	learn: 0.1510779	total: 2.14s	remaining: 950ms
# 693:	learn: 0.1508907	total: 2.15s	remaining: 947ms
# 694:	learn: 0.1507854	total: 2.15s	remaining: 944ms
# 695:	learn: 0.1506780	total: 2.15s	remaining: 940ms
# 696:	learn: 0.1505243	total: 2.15s	remaining: 937ms
# 697:	learn: 0.1503526	total: 2.16s	remaining: 933ms
# 698:	learn: 0.1502260	total: 2.16s	remaining: 930ms
# 699:	learn: 0.1501139	total: 2.16s	remaining: 927ms
# 700:	learn: 0.1500165	total: 2.16s	remaining: 923ms
# 701:	learn: 0.1498533	total: 2.17s	remaining: 920ms
# 702:	learn: 0.1497014	total: 2.17s	remaining: 917ms
# 703:	learn: 0.1496068	total: 2.17s	remaining: 914ms
# 704:	learn: 0.1494573	total: 2.17s	remaining: 910ms
# 705:	learn: 0.1493468	total: 2.18s	remaining: 907ms
# 706:	learn: 0.1491984	total: 2.18s	remaining: 904ms
# 707:	learn: 0.1490661	total: 2.18s	remaining: 901ms
# 708:	learn: 0.1489823	total: 2.19s	remaining: 898ms
# 709:	learn: 0.1488621	total: 2.19s	remaining: 895ms
# 710:	learn: 0.1487301	total: 2.19s	remaining: 892ms
# 711:	learn: 0.1485833	total: 2.2s	remaining: 890ms
# 712:	learn: 0.1484938	total: 2.2s	remaining: 886ms
# 713:	learn: 0.1484235	total: 2.2s	remaining: 883ms
# 714:	learn: 0.1482502	total: 2.21s	remaining: 880ms
# 715:	learn: 0.1481144	total: 2.21s	remaining: 877ms
# 716:	learn: 0.1480238	total: 2.21s	remaining: 873ms
# 717:	learn: 0.1478726	total: 2.21s	remaining: 870ms
# 718:	learn: 0.1477534	total: 2.22s	remaining: 867ms
# 719:	learn: 0.1476255	total: 2.22s	remaining: 863ms
# 720:	learn: 0.1474942	total: 2.22s	remaining: 860ms
# 721:	learn: 0.1473782	total: 2.23s	remaining: 857ms
# 722:	learn: 0.1472697	total: 2.23s	remaining: 854ms
# 723:	learn: 0.1470905	total: 2.23s	remaining: 851ms
# 724:	learn: 0.1469047	total: 2.23s	remaining: 848ms
# 725:	learn: 0.1467846	total: 2.24s	remaining: 845ms
# 726:	learn: 0.1465885	total: 2.24s	remaining: 841ms
# 727:	learn: 0.1464813	total: 2.24s	remaining: 838ms
# 728:	learn: 0.1463388	total: 2.25s	remaining: 835ms
# 729:	learn: 0.1462445	total: 2.25s	remaining: 831ms
# 730:	learn: 0.1461052	total: 2.25s	remaining: 828ms
# 731:	learn: 0.1460173	total: 2.25s	remaining: 825ms
# 732:	learn: 0.1458833	total: 2.26s	remaining: 822ms
# 733:	learn: 0.1458255	total: 2.26s	remaining: 819ms
# 734:	learn: 0.1457040	total: 2.26s	remaining: 816ms
# 735:	learn: 0.1456277	total: 2.27s	remaining: 812ms
# 736:	learn: 0.1455127	total: 2.27s	remaining: 809ms
# 737:	learn: 0.1453639	total: 2.27s	remaining: 806ms
# 738:	learn: 0.1452646	total: 2.27s	remaining: 803ms
# 739:	learn: 0.1451751	total: 2.27s	remaining: 799ms
# 740:	learn: 0.1450877	total: 2.28s	remaining: 796ms
# 741:	learn: 0.1450329	total: 2.28s	remaining: 793ms
# 742:	learn: 0.1449317	total: 2.28s	remaining: 790ms
# 743:	learn: 0.1448223	total: 2.29s	remaining: 787ms
# 744:	learn: 0.1446982	total: 2.29s	remaining: 784ms
# 745:	learn: 0.1446067	total: 2.29s	remaining: 781ms
# 746:	learn: 0.1445056	total: 2.3s	remaining: 778ms
# 747:	learn: 0.1443665	total: 2.3s	remaining: 775ms
# 748:	learn: 0.1442977	total: 2.3s	remaining: 772ms
# 749:	learn: 0.1442233	total: 2.31s	remaining: 769ms
# 750:	learn: 0.1440306	total: 2.31s	remaining: 766ms
# 751:	learn: 0.1439110	total: 2.31s	remaining: 762ms
# 752:	learn: 0.1438622	total: 2.31s	remaining: 759ms
# 753:	learn: 0.1436760	total: 2.32s	remaining: 756ms
# 754:	learn: 0.1435832	total: 2.32s	remaining: 753ms
# 755:	learn: 0.1434817	total: 2.32s	remaining: 749ms
# 756:	learn: 0.1433039	total: 2.32s	remaining: 746ms
# 757:	learn: 0.1431384	total: 2.33s	remaining: 743ms
# 758:	learn: 0.1430762	total: 2.33s	remaining: 740ms
# 759:	learn: 0.1429841	total: 2.33s	remaining: 736ms
# 760:	learn: 0.1428634	total: 2.33s	remaining: 733ms
# 761:	learn: 0.1427810	total: 2.34s	remaining: 730ms
# 762:	learn: 0.1426580	total: 2.34s	remaining: 727ms
# 763:	learn: 0.1425440	total: 2.34s	remaining: 723ms
# 764:	learn: 0.1423865	total: 2.34s	remaining: 720ms
# 765:	learn: 0.1422666	total: 2.35s	remaining: 717ms
# 766:	learn: 0.1421624	total: 2.35s	remaining: 714ms
# 767:	learn: 0.1420511	total: 2.35s	remaining: 710ms
# 768:	learn: 0.1419071	total: 2.35s	remaining: 707ms
# 769:	learn: 0.1417735	total: 2.36s	remaining: 704ms
# 770:	learn: 0.1416720	total: 2.36s	remaining: 701ms
# 771:	learn: 0.1415249	total: 2.36s	remaining: 698ms
# 772:	learn: 0.1414226	total: 2.37s	remaining: 695ms
# 773:	learn: 0.1412492	total: 2.37s	remaining: 691ms
# 774:	learn: 0.1411292	total: 2.37s	remaining: 688ms
# 775:	learn: 0.1410057	total: 2.37s	remaining: 685ms
# 776:	learn: 0.1408733	total: 2.38s	remaining: 682ms
# 777:	learn: 0.1408010	total: 2.38s	remaining: 679ms
# 778:	learn: 0.1407265	total: 2.39s	remaining: 677ms
# 779:	learn: 0.1405699	total: 2.39s	remaining: 674ms
# 780:	learn: 0.1404551	total: 2.39s	remaining: 671ms
# 781:	learn: 0.1403414	total: 2.4s	remaining: 668ms
# 782:	learn: 0.1403012	total: 2.4s	remaining: 665ms
# 783:	learn: 0.1401894	total: 2.4s	remaining: 662ms
# 784:	learn: 0.1401281	total: 2.4s	remaining: 659ms
# 785:	learn: 0.1399770	total: 2.41s	remaining: 656ms
# 786:	learn: 0.1398187	total: 2.41s	remaining: 652ms
# 787:	learn: 0.1396721	total: 2.41s	remaining: 649ms
# 788:	learn: 0.1395510	total: 2.42s	remaining: 646ms
# 789:	learn: 0.1394244	total: 2.42s	remaining: 643ms
# 790:	learn: 0.1393294	total: 2.42s	remaining: 640ms
# 791:	learn: 0.1392450	total: 2.42s	remaining: 637ms
# 792:	learn: 0.1390804	total: 2.43s	remaining: 634ms
# 793:	learn: 0.1389534	total: 2.43s	remaining: 630ms
# 794:	learn: 0.1388178	total: 2.43s	remaining: 627ms
# 795:	learn: 0.1386650	total: 2.44s	remaining: 624ms
# 796:	learn: 0.1385601	total: 2.44s	remaining: 621ms
# 797:	learn: 0.1384353	total: 2.44s	remaining: 618ms
# 798:	learn: 0.1383387	total: 2.44s	remaining: 614ms
# 799:	learn: 0.1382764	total: 2.44s	remaining: 611ms
# 800:	learn: 0.1381777	total: 2.45s	remaining: 608ms
# 801:	learn: 0.1380859	total: 2.45s	remaining: 605ms
# 802:	learn: 0.1379600	total: 2.46s	remaining: 602ms
# 803:	learn: 0.1378655	total: 2.46s	remaining: 600ms
# 804:	learn: 0.1377190	total: 2.46s	remaining: 597ms
# 805:	learn: 0.1375924	total: 2.47s	remaining: 594ms
# 806:	learn: 0.1374565	total: 2.47s	remaining: 590ms
# 807:	learn: 0.1373252	total: 2.47s	remaining: 587ms
# 808:	learn: 0.1372337	total: 2.48s	remaining: 585ms
# 809:	learn: 0.1371034	total: 2.48s	remaining: 582ms
# 810:	learn: 0.1370117	total: 2.48s	remaining: 579ms
# 811:	learn: 0.1369693	total: 2.49s	remaining: 576ms
# 812:	learn: 0.1368822	total: 2.49s	remaining: 573ms
# 813:	learn: 0.1366922	total: 2.49s	remaining: 570ms
# 814:	learn: 0.1365647	total: 2.5s	remaining: 567ms
# 815:	learn: 0.1364431	total: 2.5s	remaining: 563ms
# 816:	learn: 0.1363584	total: 2.5s	remaining: 560ms
# 817:	learn: 0.1362122	total: 2.51s	remaining: 558ms
# 818:	learn: 0.1360399	total: 2.51s	remaining: 555ms
# 819:	learn: 0.1359408	total: 2.52s	remaining: 552ms
# 820:	learn: 0.1357845	total: 2.52s	remaining: 549ms
# 821:	learn: 0.1356605	total: 2.52s	remaining: 546ms
# 822:	learn: 0.1355804	total: 2.52s	remaining: 543ms
# 823:	learn: 0.1354036	total: 2.53s	remaining: 540ms
# 824:	learn: 0.1352450	total: 2.53s	remaining: 536ms
# 825:	learn: 0.1351222	total: 2.53s	remaining: 533ms
# 826:	learn: 0.1350189	total: 2.53s	remaining: 530ms
# 827:	learn: 0.1348962	total: 2.54s	remaining: 527ms
# 828:	learn: 0.1348244	total: 2.54s	remaining: 524ms
# 829:	learn: 0.1346650	total: 2.54s	remaining: 521ms
# 830:	learn: 0.1345240	total: 2.54s	remaining: 518ms
# 831:	learn: 0.1344427	total: 2.55s	remaining: 514ms
# 832:	learn: 0.1342742	total: 2.55s	remaining: 511ms
# 833:	learn: 0.1341979	total: 2.55s	remaining: 508ms
# 834:	learn: 0.1340212	total: 2.56s	remaining: 505ms
# 835:	learn: 0.1339477	total: 2.56s	remaining: 502ms
# 836:	learn: 0.1338090	total: 2.56s	remaining: 499ms
# 837:	learn: 0.1337597	total: 2.57s	remaining: 498ms
# 838:	learn: 0.1337030	total: 2.58s	remaining: 496ms
# 839:	learn: 0.1336144	total: 2.58s	remaining: 493ms
# 840:	learn: 0.1334276	total: 2.59s	remaining: 489ms
# 841:	learn: 0.1333704	total: 2.6s	remaining: 488ms
# 842:	learn: 0.1333194	total: 2.6s	remaining: 485ms
# 843:	learn: 0.1332297	total: 2.6s	remaining: 482ms
# 844:	learn: 0.1331484	total: 2.61s	remaining: 480ms
# 845:	learn: 0.1330400	total: 2.62s	remaining: 476ms
# 846:	learn: 0.1329249	total: 2.62s	remaining: 473ms
# 847:	learn: 0.1328303	total: 2.62s	remaining: 470ms
# 848:	learn: 0.1327490	total: 2.62s	remaining: 467ms
# 849:	learn: 0.1326906	total: 2.63s	remaining: 464ms
# 850:	learn: 0.1326205	total: 2.63s	remaining: 461ms
# 851:	learn: 0.1325607	total: 2.63s	remaining: 457ms
# 852:	learn: 0.1324068	total: 2.63s	remaining: 454ms
# 853:	learn: 0.1322341	total: 2.64s	remaining: 451ms
# 854:	learn: 0.1320625	total: 2.64s	remaining: 448ms
# 855:	learn: 0.1318999	total: 2.64s	remaining: 445ms
# 856:	learn: 0.1318555	total: 2.65s	remaining: 441ms
# 857:	learn: 0.1317270	total: 2.65s	remaining: 438ms
# 858:	learn: 0.1316300	total: 2.65s	remaining: 435ms
# 859:	learn: 0.1316068	total: 2.65s	remaining: 432ms
# 860:	learn: 0.1315307	total: 2.65s	remaining: 429ms
# 861:	learn: 0.1314138	total: 2.66s	remaining: 426ms
# 862:	learn: 0.1313022	total: 2.67s	remaining: 424ms
# 863:	learn: 0.1311964	total: 2.67s	remaining: 420ms
# 864:	learn: 0.1311274	total: 2.67s	remaining: 417ms
# 865:	learn: 0.1310299	total: 2.68s	remaining: 414ms
# 866:	learn: 0.1308739	total: 2.68s	remaining: 411ms
# 867:	learn: 0.1308000	total: 2.68s	remaining: 408ms
# 868:	learn: 0.1306915	total: 2.68s	remaining: 405ms
# 869:	learn: 0.1305710	total: 2.69s	remaining: 401ms
# 870:	learn: 0.1304551	total: 2.69s	remaining: 398ms
# 871:	learn: 0.1303518	total: 2.69s	remaining: 395ms
# 872:	learn: 0.1302854	total: 2.69s	remaining: 392ms
# 873:	learn: 0.1301112	total: 2.7s	remaining: 389ms
# 874:	learn: 0.1300095	total: 2.7s	remaining: 386ms
# 875:	learn: 0.1299064	total: 2.7s	remaining: 382ms
# 876:	learn: 0.1297691	total: 2.7s	remaining: 379ms
# 877:	learn: 0.1296711	total: 2.71s	remaining: 376ms
# 878:	learn: 0.1295704	total: 2.71s	remaining: 373ms
# 879:	learn: 0.1294720	total: 2.71s	remaining: 370ms
# 880:	learn: 0.1293482	total: 2.71s	remaining: 367ms
# 881:	learn: 0.1292574	total: 2.72s	remaining: 364ms
# 882:	learn: 0.1291495	total: 2.72s	remaining: 361ms
# 883:	learn: 0.1290348	total: 2.72s	remaining: 357ms
# 884:	learn: 0.1289465	total: 2.73s	remaining: 354ms
# 885:	learn: 0.1288595	total: 2.73s	remaining: 351ms
# 886:	learn: 0.1288224	total: 2.73s	remaining: 348ms
# 887:	learn: 0.1287011	total: 2.74s	remaining: 345ms
# 888:	learn: 0.1286328	total: 2.74s	remaining: 342ms
# 889:	learn: 0.1286129	total: 2.74s	remaining: 339ms
# 890:	learn: 0.1284873	total: 2.74s	remaining: 336ms
# 891:	learn: 0.1284262	total: 2.75s	remaining: 333ms
# 892:	learn: 0.1282559	total: 2.75s	remaining: 329ms
# 893:	learn: 0.1281896	total: 2.75s	remaining: 326ms
# 894:	learn: 0.1280844	total: 2.76s	remaining: 323ms
# 895:	learn: 0.1280046	total: 2.76s	remaining: 320ms
# 896:	learn: 0.1279456	total: 2.76s	remaining: 317ms
# 897:	learn: 0.1278260	total: 2.77s	remaining: 314ms
# 898:	learn: 0.1277240	total: 2.77s	remaining: 311ms
# 899:	learn: 0.1276019	total: 2.77s	remaining: 308ms
# 900:	learn: 0.1274875	total: 2.78s	remaining: 305ms
# 901:	learn: 0.1273587	total: 2.78s	remaining: 302ms
# 902:	learn: 0.1272942	total: 2.78s	remaining: 299ms
# 903:	learn: 0.1272378	total: 2.78s	remaining: 296ms
# 904:	learn: 0.1271420	total: 2.79s	remaining: 293ms
# 905:	learn: 0.1270100	total: 2.79s	remaining: 290ms
# 906:	learn: 0.1269320	total: 2.79s	remaining: 286ms
# 907:	learn: 0.1268776	total: 2.79s	remaining: 283ms
# 908:	learn: 0.1267968	total: 2.8s	remaining: 280ms
# 909:	learn: 0.1266772	total: 2.8s	remaining: 277ms
# 910:	learn: 0.1265847	total: 2.8s	remaining: 274ms
# 911:	learn: 0.1264963	total: 2.81s	remaining: 271ms
# 912:	learn: 0.1264525	total: 2.81s	remaining: 268ms
# 913:	learn: 0.1263737	total: 2.81s	remaining: 264ms
# 914:	learn: 0.1262919	total: 2.81s	remaining: 261ms
# 915:	learn: 0.1262377	total: 2.81s	remaining: 258ms
# 916:	learn: 0.1261387	total: 2.82s	remaining: 255ms
# 917:	learn: 0.1260732	total: 2.82s	remaining: 252ms
# 918:	learn: 0.1259693	total: 2.82s	remaining: 249ms
# 919:	learn: 0.1258850	total: 2.83s	remaining: 246ms
# 920:	learn: 0.1258174	total: 2.83s	remaining: 243ms
# 921:	learn: 0.1257277	total: 2.83s	remaining: 240ms
# 922:	learn: 0.1256516	total: 2.83s	remaining: 236ms
# 923:	learn: 0.1255392	total: 2.84s	remaining: 233ms
# 924:	learn: 0.1254410	total: 2.84s	remaining: 230ms
# 925:	learn: 0.1253369	total: 2.84s	remaining: 227ms
# 926:	learn: 0.1252516	total: 2.84s	remaining: 224ms
# 927:	learn: 0.1250863	total: 2.85s	remaining: 221ms
# 928:	learn: 0.1249798	total: 2.85s	remaining: 218ms
# 929:	learn: 0.1248849	total: 2.85s	remaining: 215ms
# 930:	learn: 0.1248313	total: 2.85s	remaining: 212ms
# 931:	learn: 0.1247469	total: 2.86s	remaining: 209ms
# 932:	learn: 0.1246646	total: 2.86s	remaining: 206ms
# 933:	learn: 0.1245545	total: 2.87s	remaining: 203ms
# 934:	learn: 0.1244642	total: 2.87s	remaining: 200ms
# 935:	learn: 0.1243928	total: 2.87s	remaining: 197ms
# 936:	learn: 0.1242937	total: 2.88s	remaining: 194ms
# 937:	learn: 0.1242518	total: 2.88s	remaining: 190ms
# 938:	learn: 0.1241845	total: 2.89s	remaining: 188ms
# 939:	learn: 0.1240396	total: 2.89s	remaining: 184ms
# 940:	learn: 0.1239501	total: 2.89s	remaining: 181ms
# 941:	learn: 0.1238383	total: 2.89s	remaining: 178ms
# 942:	learn: 0.1236480	total: 2.9s	remaining: 175ms
# 943:	learn: 0.1235759	total: 2.9s	remaining: 172ms
# 944:	learn: 0.1234921	total: 2.9s	remaining: 169ms
# 945:	learn: 0.1233874	total: 2.9s	remaining: 166ms
# 946:	learn: 0.1233303	total: 2.91s	remaining: 163ms
# 947:	learn: 0.1232739	total: 2.91s	remaining: 160ms
# 948:	learn: 0.1231364	total: 2.91s	remaining: 156ms
# 949:	learn: 0.1230011	total: 2.91s	remaining: 153ms
# 950:	learn: 0.1229432	total: 2.92s	remaining: 150ms
# 951:	learn: 0.1228629	total: 2.92s	remaining: 147ms
# 952:	learn: 0.1227933	total: 2.92s	remaining: 144ms
# 953:	learn: 0.1227637	total: 2.92s	remaining: 141ms
# 954:	learn: 0.1226157	total: 2.92s	remaining: 138ms
# 955:	learn: 0.1224964	total: 2.93s	remaining: 135ms
# 956:	learn: 0.1224221	total: 2.93s	remaining: 132ms
# 957:	learn: 0.1222472	total: 2.93s	remaining: 129ms
# 958:	learn: 0.1221832	total: 2.94s	remaining: 125ms
# 959:	learn: 0.1221303	total: 2.94s	remaining: 122ms
# 960:	learn: 0.1220792	total: 2.94s	remaining: 119ms
# 961:	learn: 0.1219736	total: 2.94s	remaining: 116ms
# 962:	learn: 0.1218857	total: 2.94s	remaining: 113ms
# 963:	learn: 0.1217755	total: 2.95s	remaining: 110ms
# 964:	learn: 0.1217282	total: 2.96s	remaining: 107ms
# 965:	learn: 0.1216549	total: 2.96s	remaining: 104ms
# 966:	learn: 0.1215173	total: 2.96s	remaining: 101ms
# 967:	learn: 0.1214632	total: 2.96s	remaining: 98ms
# 968:	learn: 0.1213470	total: 2.97s	remaining: 94.9ms
# 969:	learn: 0.1212513	total: 2.97s	remaining: 91.8ms
# 970:	learn: 0.1212281	total: 2.97s	remaining: 88.8ms
# 971:	learn: 0.1211567	total: 2.97s	remaining: 85.7ms
# 972:	learn: 0.1210811	total: 2.98s	remaining: 82.7ms
# 973:	learn: 0.1209909	total: 2.98s	remaining: 79.7ms
# 974:	learn: 0.1209378	total: 2.99s	remaining: 76.6ms
# 975:	learn: 0.1208638	total: 2.99s	remaining: 73.6ms
# 976:	learn: 0.1208001	total: 2.99s	remaining: 70.5ms
# 977:	learn: 0.1207078	total: 3s	remaining: 67.4ms
# 978:	learn: 0.1206113	total: 3s	remaining: 64.3ms
# 979:	learn: 0.1205045	total: 3s	remaining: 61.3ms
# 980:	learn: 0.1204103	total: 3s	remaining: 58.2ms
# 981:	learn: 0.1203373	total: 3.01s	remaining: 55.1ms
# 982:	learn: 0.1202431	total: 3.01s	remaining: 52.1ms
# 983:	learn: 0.1201669	total: 3.02s	remaining: 49.1ms
# 984:	learn: 0.1200625	total: 3.02s	remaining: 46ms
# 985:	learn: 0.1200113	total: 3.02s	remaining: 42.9ms
# 986:	learn: 0.1199498	total: 3.03s	remaining: 39.9ms
# 987:	learn: 0.1198618	total: 3.03s	remaining: 36.8ms
# 988:	learn: 0.1196395	total: 3.03s	remaining: 33.7ms
# 989:	learn: 0.1195516	total: 3.04s	remaining: 30.7ms
# 990:	learn: 0.1194745	total: 3.04s	remaining: 27.6ms
# 991:	learn: 0.1193945	total: 3.05s	remaining: 24.6ms
# 992:	learn: 0.1192613	total: 3.05s	remaining: 21.5ms
# 993:	learn: 0.1192175	total: 3.05s	remaining: 18.4ms
# 994:	learn: 0.1191280	total: 3.06s	remaining: 15.4ms
# 995:	learn: 0.1190266	total: 3.06s	remaining: 12.3ms
# 996:	learn: 0.1188952	total: 3.06s	remaining: 9.21ms
# 997:	learn: 0.1188127	total: 3.06s	remaining: 6.14ms
# 998:	learn: 0.1187051	total: 3.07s	remaining: 3.07ms
# 999:	learn: 0.1186326	total: 3.07s	remaining: 0us

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test , y_predict))
pd.crosstab(y_test , y_predict)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.82      0.89       939
#            1       0.11      0.51      0.19        43
#
#     accuracy                           0.80       982
#    macro avg       0.54      0.66      0.54       982
# weighted avg       0.94      0.80      0.86       982
# col_0    0    1
# row_0
# 0      768  171
# 1       21   22

# %%
from sklearn.metrics import accuracy_score
f=accuracy_score(y_test, y_predict)
f
# Out:
# 0.8044806517311609

# %% [markdown]
# # **Result of our prediction**

# %%
plt.figure(figsize=[10,6])
left=[1,2,3,4,5]
high=[a,b,c,d,f]
tic=['regression' , 'k_nearest' , 'decission trees' , 'xgboost' , 'catboost']
plt.bar(left, high ,tick_label=tic  ,width=0.5 ,color=['green' , 'blue' ,'yellow' ,'red','black'])
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# Best Model for our data is decission trees but Naive bayes classification is the best model for predict our lowes class(class 1).

# %%
from sklearn import datasets
from sklearn.metrics import roc_curve, roc_auc_score

# %%
rf_predict=lo.predict(x_test)
nb_predict=classifier.predict(x_test)
lg_predict=random.predict(x_test)
kn_predict=classifier.predict(x_test)
xg_predict=model.predict(x_test)
ca_predict=cat.predict(x_test)

# %%
rf_auc=roc_auc_score(y_test,rf_predict)
nb_auc=roc_auc_score(y_test,nb_predict)
lg_auc=roc_auc_score(y_test,lg_predict)
kn_auc=roc_auc_score(y_test,kn_predict)
xg_auc=roc_auc_score(y_test,xg_predict)
ca_auc=roc_auc_score(y_test,ca_predict)

# %%
rf_fpr,rf_tpr,_ =roc_curve(y_test,rf_predict)
nb_fpr,nb_tpr,_ =roc_curve(y_test,nb_predict)
lg_fpr,lg_tpr,_ =roc_curve(y_test,lg_predict)
kn_fpr,kn_tpr,_ =roc_curve(y_test,kn_predict)
xg_fpr,xg_tpr,_ =roc_curve(y_test,xg_predict)
ca_fpr,ca_tpr,_ =roc_curve(y_test,ca_predict)

# %%
plt.subplots(1, figsize=(10,10))
r=[0,0.5,1]
p=r
plt.plot(r,p , linestyle='-', label='base')
plt.plot(rf_fpr,rf_tpr , linestyle='--' , label='random forest')
plt.plot(nb_fpr,nb_tpr , linestyle='--' , label='naive bayes')
plt.plot(lg_fpr,lg_tpr , linestyle='--' , label='regression')
plt.plot(kn_fpr,kn_tpr , linestyle='--' , label='k_nearest')
plt.plot(xg_fpr,xg_tpr , linestyle='--' , label='xgboost')
plt.plot(ca_fpr,ca_tpr , linestyle='--' , label='catboost')



plt.title('ROC curve_gain chart')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.legend()
plt.show()
